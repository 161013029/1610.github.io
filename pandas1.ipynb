# %%
import pandas as pd

# %%
import glob
print(glob.glob("*.csv"))
# Out:
# ['_GDP.csv', '_POP.csv']

# %%
df_try = pd.read_table("_GDP.csv",   #读GDP数据，赋与df   (df指 dataframe)   pd.DataFrame 是前面最早调用的 pandas
                       encoding = 'utf8',        
                      )

# %%
df_try
# Out:
#                                  数据库：分省年度数据,,,,,,,,,,
# 0                             指标：地区生产总值（亿元）,,,,,,,,,,
# 1                             时间：2006-2015年,,,,,,,,,,
# 2   地区,2006年,2007年,2008年,2009年,2010年,2011年,2012年,2...
# 3   北京市,8117.8,9846.81,11115,12153.03,14113.58,162...
# 4   天津市,4462.74,5252.76,6719.01,7521.85,9224.46,11...
# 5   河北省,11467.6,13607.32,16011.97,17235.48,20394.2...
# 6   山西省,4878.61,6024.45,7315.4,7358.31,9200.86,112...
# 7   内蒙古自治区,4944.25,6423.18,8496.2,9740.25,11672,14...
# 8   辽宁省,9304.52,11164.3,13668.58,15212.49,18457.27...
# 9   吉林省,4275.12,5284.69,6426.1,7278.75,8667.58,105...
# 10  黑龙江省,6211.8,7104,8314.37,8587,10368.6,12582,13...
# 11  上海市,10572.24,12494.01,14069.86,15046.45,17165....
# 12  江苏省,21742.05,26018.48,30981.98,34457.3,41425.4...
# 13  浙江省,15718.47,18753.73,21462.69,22990.35,27722....
# 14  安徽省,6112.5,7360.92,8851.66,10062.82,12359.33,1...
# 15  福建省,7583.85,9248.53,10823.01,12236.53,14737.12...
# 16  江西省,4820.53,5800.25,6971.05,7655.18,9451.26,11...
# 17  山东省,21900.19,25776.91,30933.28,33896.65,39169....
# 18  河南省,12362.79,15012.46,18018.53,19480.46,23092....
# 19  湖北省,7617.47,9333.4,11328.92,12961.1,15967.61,1...
# 20  湖南省,7688.67,9439.6,11555,13059.69,16037.96,196...
# 21  广东省,26587.76,31777.01,36796.71,39482.56,46013....
# 22  广西壮族自治区,4746.16,5823.41,7021,7759.16,9569.85,1...
# 23  海南省,1065.67,1254.17,1503.06,1654.21,2064.5,252...
# 24  重庆市,3907.23,4676.13,5793.66,6530.01,7925.58,10...
# 25  四川省,8690.24,10562.39,12601.23,14151.28,17185.4...
# 26  贵州省,2338.98,2884.11,3561.56,3912.68,4602.16,57...
# 27  云南省,3988.14,4772.52,5692.12,6169.75,7224.18,88...
# 28  西藏自治区,290.76,341.43,394.85,441.36,507.46,605.8...
# 29  陕西省,4743.61,5757.29,7314.58,8169.8,10123.48,12...
# 30  甘肃省,2277.35,2703.98,3166.82,3387.56,4120.75,50...
# 31  青海省,648.5,797.35,1018.62,1081.27,1350.43,1670....
# 32  宁夏回族自治区,725.9,919.11,1203.92,1353.31,1689.65,2...
# 33  新疆维吾尔自治区,3045.26,3523.16,4183.21,4277.05,5437....

# %%
df    = pd.read_table("_GDP.csv",  # 使用skiprows 跳过上面的最後2行
                       encoding = 'utf8',      
                       header = 3               # 指定数据的标题为原始数据之第3行
                     )
df
# Out:
#    地区,2006年,2007年,2008年,2009年,2010年,2011年,2012年,2013年,2014年,2015年
# 0   北京市,8117.8,9846.81,11115,12153.03,14113.58,162...
# 1   天津市,4462.74,5252.76,6719.01,7521.85,9224.46,11...
# 2   河北省,11467.6,13607.32,16011.97,17235.48,20394.2...
# 3   山西省,4878.61,6024.45,7315.4,7358.31,9200.86,112...
# 4   内蒙古自治区,4944.25,6423.18,8496.2,9740.25,11672,14...
# 5   辽宁省,9304.52,11164.3,13668.58,15212.49,18457.27...
# 6   吉林省,4275.12,5284.69,6426.1,7278.75,8667.58,105...
# 7   黑龙江省,6211.8,7104,8314.37,8587,10368.6,12582,13...
# 8   上海市,10572.24,12494.01,14069.86,15046.45,17165....
# 9   江苏省,21742.05,26018.48,30981.98,34457.3,41425.4...
# 10  浙江省,15718.47,18753.73,21462.69,22990.35,27722....
# 11  安徽省,6112.5,7360.92,8851.66,10062.82,12359.33,1...
# 12  福建省,7583.85,9248.53,10823.01,12236.53,14737.12...
# 13  江西省,4820.53,5800.25,6971.05,7655.18,9451.26,11...
# 14  山东省,21900.19,25776.91,30933.28,33896.65,39169....
# 15  河南省,12362.79,15012.46,18018.53,19480.46,23092....
# 16  湖北省,7617.47,9333.4,11328.92,12961.1,15967.61,1...
# 17  湖南省,7688.67,9439.6,11555,13059.69,16037.96,196...
# 18  广东省,26587.76,31777.01,36796.71,39482.56,46013....
# 19  广西壮族自治区,4746.16,5823.41,7021,7759.16,9569.85,1...
# 20  海南省,1065.67,1254.17,1503.06,1654.21,2064.5,252...
# 21  重庆市,3907.23,4676.13,5793.66,6530.01,7925.58,10...
# 22  四川省,8690.24,10562.39,12601.23,14151.28,17185.4...
# 23  贵州省,2338.98,2884.11,3561.56,3912.68,4602.16,57...
# 24  云南省,3988.14,4772.52,5692.12,6169.75,7224.18,88...
# 25  西藏自治区,290.76,341.43,394.85,441.36,507.46,605.8...
# 26  陕西省,4743.61,5757.29,7314.58,8169.8,10123.48,12...
# 27  甘肃省,2277.35,2703.98,3166.82,3387.56,4120.75,50...
# 28  青海省,648.5,797.35,1018.62,1081.27,1350.43,1670....
# 29  宁夏回族自治区,725.9,919.11,1203.92,1353.31,1689.65,2...
# 30  新疆维吾尔自治区,3045.26,3523.16,4183.21,4277.05,5437....

# %%
df    = pd.read_table("_GDP.csv",   
                       encoding = 'utf8',      
                       header = 3,              # 指定数据的标题为原始数据之第3行
                       skiprows = [35,36]       # 原始数据之第35, 36行跳过不计
                     )
df
# Out:
#    地区,2006年,2007年,2008年,2009年,2010年,2011年,2012年,2013年,2014年,2015年
# 0   北京市,8117.8,9846.81,11115,12153.03,14113.58,162...
# 1   天津市,4462.74,5252.76,6719.01,7521.85,9224.46,11...
# 2   河北省,11467.6,13607.32,16011.97,17235.48,20394.2...
# 3   山西省,4878.61,6024.45,7315.4,7358.31,9200.86,112...
# 4   内蒙古自治区,4944.25,6423.18,8496.2,9740.25,11672,14...
# 5   辽宁省,9304.52,11164.3,13668.58,15212.49,18457.27...
# 6   吉林省,4275.12,5284.69,6426.1,7278.75,8667.58,105...
# 7   黑龙江省,6211.8,7104,8314.37,8587,10368.6,12582,13...
# 8   上海市,10572.24,12494.01,14069.86,15046.45,17165....
# 9   江苏省,21742.05,26018.48,30981.98,34457.3,41425.4...
# 10  浙江省,15718.47,18753.73,21462.69,22990.35,27722....
# 11  安徽省,6112.5,7360.92,8851.66,10062.82,12359.33,1...
# 12  福建省,7583.85,9248.53,10823.01,12236.53,14737.12...
# 13  江西省,4820.53,5800.25,6971.05,7655.18,9451.26,11...
# 14  山东省,21900.19,25776.91,30933.28,33896.65,39169....
# 15  河南省,12362.79,15012.46,18018.53,19480.46,23092....
# 16  湖北省,7617.47,9333.4,11328.92,12961.1,15967.61,1...
# 17  湖南省,7688.67,9439.6,11555,13059.69,16037.96,196...
# 18  广东省,26587.76,31777.01,36796.71,39482.56,46013....
# 19  广西壮族自治区,4746.16,5823.41,7021,7759.16,9569.85,1...
# 20  海南省,1065.67,1254.17,1503.06,1654.21,2064.5,252...
# 21  重庆市,3907.23,4676.13,5793.66,6530.01,7925.58,10...
# 22  四川省,8690.24,10562.39,12601.23,14151.28,17185.4...
# 23  贵州省,2338.98,2884.11,3561.56,3912.68,4602.16,57...
# 24  云南省,3988.14,4772.52,5692.12,6169.75,7224.18,88...
# 25  西藏自治区,290.76,341.43,394.85,441.36,507.46,605.8...
# 26  陕西省,4743.61,5757.29,7314.58,8169.8,10123.48,12...
# 27  甘肃省,2277.35,2703.98,3166.82,3387.56,4120.75,50...
# 28  青海省,648.5,797.35,1018.62,1081.27,1350.43,1670....
# 29  宁夏回族自治区,725.9,919.11,1203.92,1353.31,1689.65,2...
# 30  新疆维吾尔自治区,3045.26,3523.16,4183.21,4277.05,5437....

# %%
df    = pd.read_table("_GDP.csv",   
                       encoding = 'utf8',       
                       header = 3,              # 指定数据的标题为原始数据之第3行
                       skiprows = [35,36],      # 原始数据之第35, 36行跳过不计
                       sep =','                 # 分隔符设为',' read_table内置分隔符为\t
                     )
df
# Out:
#           地区     2006年     2007年     2008年     2009年     2010年     2011年  \
# 0        北京市   8117.80   9846.81  11115.00  12153.03  14113.58  16251.93
# 1        天津市   4462.74   5252.76   6719.01   7521.85   9224.46  11307.28
# 2        河北省  11467.60  13607.32  16011.97  17235.48  20394.26  24515.76
# 3        山西省   4878.61   6024.45   7315.40   7358.31   9200.86  11237.55
# 4     内蒙古自治区   4944.25   6423.18   8496.20   9740.25  11672.00  14359.88
# 5        辽宁省   9304.52  11164.30  13668.58  15212.49  18457.27  22226.70
# 6        吉林省   4275.12   5284.69   6426.10   7278.75   8667.58  10568.83
# 7       黑龙江省   6211.80   7104.00   8314.37   8587.00  10368.60  12582.00
# 8        上海市  10572.24  12494.01  14069.86  15046.45  17165.98  19195.69
# 9        江苏省  21742.05  26018.48  30981.98  34457.30  41425.48  49110.27
# 10       浙江省  15718.47  18753.73  21462.69  22990.35  27722.31  32318.85
# 11       安徽省   6112.50   7360.92   8851.66  10062.82  12359.33  15300.65
# 12       福建省   7583.85   9248.53  10823.01  12236.53  14737.12  17560.18
# 13       江西省   4820.53   5800.25   6971.05   7655.18   9451.26  11702.82
# 14       山东省  21900.19  25776.91  30933.28  33896.65  39169.92  45361.85
# 15       河南省  12362.79  15012.46  18018.53  19480.46  23092.36  26931.03
# 16       湖北省   7617.47   9333.40  11328.92  12961.10  15967.61  19632.26
# 17       湖南省   7688.67   9439.60  11555.00  13059.69  16037.96  19669.56
# 18       广东省  26587.76  31777.01  36796.71  39482.56  46013.06  53210.28
# 19   广西壮族自治区   4746.16   5823.41   7021.00   7759.16   9569.85  11720.87
# 20       海南省   1065.67   1254.17   1503.06   1654.21   2064.50   2522.66
# 21       重庆市   3907.23   4676.13   5793.66   6530.01   7925.58  10011.37
# 22       四川省   8690.24  10562.39  12601.23  14151.28  17185.48  21026.68
# 23       贵州省   2338.98   2884.11   3561.56   3912.68   4602.16   5701.84
# 24       云南省   3988.14   4772.52   5692.12   6169.75   7224.18   8893.12
# 25     西藏自治区    290.76    341.43    394.85    441.36    507.46    605.83
# 26       陕西省   4743.61   5757.29   7314.58   8169.80  10123.48  12512.30
# 27       甘肃省   2277.35   2703.98   3166.82   3387.56   4120.75   5020.37
# 28       青海省    648.50    797.35   1018.62   1081.27   1350.43   1670.44
# 29   宁夏回族自治区    725.90    919.11   1203.92   1353.31   1689.65   2102.21
# 30  新疆维吾尔自治区   3045.26   3523.16   4183.21   4277.05   5437.47   6610.05
#
#        2012年     2013年     2014年     2015年
# 0   17879.40  19800.81  21330.83  23014.59
# 1   12893.88  14442.01  15726.93  16538.19
# 2   26575.01  28442.95  29421.15  29806.11
# 3   12112.83  12665.25  12761.49  12766.49
# 4   15880.58  16916.50  17770.19  17831.51
# 5   24846.43  27213.22  28626.58  28669.02
# 6   11939.24  13046.40  13803.14  14063.13
# 7   13691.58  14454.91  15039.38  15083.67
# 8   20181.72  21818.15  23567.70  25123.45
# 9   54058.22  59753.37  65088.32  70116.38
# 10  34665.33  37756.59  40173.03  42886.49
# 11  17212.05  19229.34  20848.75  22005.63
# 12  19701.78  21868.49  24055.76  25979.82
# 13  12948.88  14410.19  15714.63  16723.78
# 14  50013.24  55230.32  59426.59  63002.33
# 15  29599.31  32191.30  34938.24  37002.16
# 16  22250.45  24791.83  27379.22  29550.19
# 17  22154.23  24621.67  27037.32  28902.21
# 18  57067.92  62474.79  67809.85  72812.55
# 19  13035.10  14449.90  15672.89  16803.12
# 20   2855.54   3177.56   3500.72   3702.76
# 21  11409.60  12783.26  14262.60  15717.27
# 22  23872.80  26392.07  28536.66  30053.10
# 23   6852.20   8086.86   9266.39  10502.56
# 24  10309.47  11832.31  12814.59  13619.17
# 25    701.03    815.67    920.83   1026.39
# 26  14453.68  16205.45  17689.94  18021.86
# 27   5650.20   6330.69   6836.82   6790.32
# 28   1893.54   2122.06   2303.32   2417.05
# 29   2341.29   2577.57   2752.10   2911.77
# 30   7505.31   8443.84   9273.46   9324.80

# %%
df.head()  # .head()只看前面5笔
# Out:
#        地区     2006年     2007年     2008年     2009年     2010年     2011年  \
# 0     北京市   8117.80   9846.81  11115.00  12153.03  14113.58  16251.93
# 1     天津市   4462.74   5252.76   6719.01   7521.85   9224.46  11307.28
# 2     河北省  11467.60  13607.32  16011.97  17235.48  20394.26  24515.76
# 3     山西省   4878.61   6024.45   7315.40   7358.31   9200.86  11237.55
# 4  内蒙古自治区   4944.25   6423.18   8496.20   9740.25  11672.00  14359.88
#
#       2012年     2013年     2014年     2015年
# 0  17879.40  19800.81  21330.83  23014.59
# 1  12893.88  14442.01  15726.93  16538.19
# 2  26575.01  28442.95  29421.15  29806.11
# 3  12112.83  12665.25  12761.49  12766.49
# 4  15880.58  16916.50  17770.19  17831.51

# %%
df_GDP= pd.read_table("_GDP.csv",   
                       encoding = 'utf8',       
                       header = 3,              
                       skiprows = [35,36],      
                       sep =','                 
                      )
df_POP= pd.read_table("_POP.csv",  
                       encoding = 'utf8',       
                       header = 3,              
                       skiprows = [35,36],     
                       sep =','                 
                      )

# %%
#练习2  准备数据
df = df_GDP

# %%
df.columns
# Out:
# Index(['地区', '2006年', '2007年', '2008年', '2009年', '2010年', '2011年', '2012年',
#        '2013年', '2014年', '2015年'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
df['地区'].head()
# Out:
# 0       北京市
# 1       天津市
# 2       河北省
# 3       山西省
# 4    内蒙古自治区
# Name: 地区, dtype: object

# %%
df['2007年'].head()
# Out:
# 0     9846.81
# 1     5252.76
# 2    13607.32
# 3     6024.45
# 4     6423.18
# Name: 2007年, dtype: float64

# %%
df.dtypes
# Out:
# 地区        object
# 2006年    float64
# 2007年    float64
# 2008年    float64
# 2009年    float64
# 2010年    float64
# 2011年    float64
# 2012年    float64
# 2013年    float64
# 2014年    float64
# 2015年    float64
# dtype: object

# %%
# 把df 的栏位用列表推导的方式清理掉'年'这个字符後转换成整数
df.columns = [ int(x.replace('年','')) if x!='地区' else x for x in df.columns] 
df.columns
# Out:
# Index(['地区', 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015], dtype='object')

# %%
years = [ x for x in df.columns if x!='地区'] #求最新的一年
max(years)
# Out:
# 2015

# %%
df_melted = pd.melt(df, id_vars=['地区'], value_vars=years)# pd.melt() 相当於Tableau 的数据透视

# %%
df_melted.columns
# Out:
# Index(['地区', 'variable', 'value'], dtype='object')

# %%
df_melted.columns = ['地区', '年', 'GDP']
df_melted
# Out:
#            地区     年       GDP
# 0         北京市  2006   8117.80
# 1         天津市  2006   4462.74
# 2         河北省  2006  11467.60
# 3         山西省  2006   4878.61
# 4      内蒙古自治区  2006   4944.25
# 5         辽宁省  2006   9304.52
# 6         吉林省  2006   4275.12
# 7        黑龙江省  2006   6211.80
# 8         上海市  2006  10572.24
# 9         江苏省  2006  21742.05
# 10        浙江省  2006  15718.47
# 11        安徽省  2006   6112.50
# 12        福建省  2006   7583.85
# 13        江西省  2006   4820.53
# 14        山东省  2006  21900.19
# 15        河南省  2006  12362.79
# 16        湖北省  2006   7617.47
# 17        湖南省  2006   7688.67
# 18        广东省  2006  26587.76
# 19    广西壮族自治区  2006   4746.16
# 20        海南省  2006   1065.67
# 21        重庆市  2006   3907.23
# 22        四川省  2006   8690.24
# 23        贵州省  2006   2338.98
# 24        云南省  2006   3988.14
# 25      西藏自治区  2006    290.76
# 26        陕西省  2006   4743.61
# 27        甘肃省  2006   2277.35
# 28        青海省  2006    648.50
# 29    宁夏回族自治区  2006    725.90
# ..        ...   ...       ...
# 280       天津市  2015  16538.19
# 281       河北省  2015  29806.11
# 282       山西省  2015  12766.49
# 283    内蒙古自治区  2015  17831.51
# 284       辽宁省  2015  28669.02
# 285       吉林省  2015  14063.13
# 286      黑龙江省  2015  15083.67
# 287       上海市  2015  25123.45
# 288       江苏省  2015  70116.38
# 289       浙江省  2015  42886.49
# 290       安徽省  2015  22005.63
# 291       福建省  2015  25979.82
# 292       江西省  2015  16723.78
# 293       山东省  2015  63002.33
# 294       河南省  2015  37002.16
# 295       湖北省  2015  29550.19
# 296       湖南省  2015  28902.21
# 297       广东省  2015  72812.55
# 298   广西壮族自治区  2015  16803.12
# 299       海南省  2015   3702.76
# 300       重庆市  2015  15717.27
# 301       四川省  2015  30053.10
# 302       贵州省  2015  10502.56
# 303       云南省  2015  13619.17
# 304     西藏自治区  2015   1026.39
# 305       陕西省  2015  18021.86
# 306       甘肃省  2015   6790.32
# 307       青海省  2015   2417.05
# 308   宁夏回族自治区  2015   2911.77
# 309  新疆维吾尔自治区  2015   9324.80
#
# [310 rows x 3 columns]

# %%
df_GDP_done = df_melted

# %%
# 再处理 df_POP
df = df_POP
df.columns = [ int(x.replace('年','')) if x!='地区' else x for x in df.columns]
years = [ x for x in df.columns if x!='地区'] 
df_melted = pd.melt(df, id_vars=['地区'], value_vars=years)
df_melted.columns = ['地区', '年', 'POP']
df_POP_done = df_melted
df_POP_done
# Out:
#            地区     年    POP
# 0         北京市  2006   1601
# 1         天津市  2006   1075
# 2         河北省  2006   6898
# 3         山西省  2006   3375
# 4      内蒙古自治区  2006   2415
# 5         辽宁省  2006   4271
# 6         吉林省  2006   2723
# 7        黑龙江省  2006   3823
# 8         上海市  2006   1964
# 9         江苏省  2006   7656
# 10        浙江省  2006   5072
# 11        安徽省  2006   6110
# 12        福建省  2006   3585
# 13        江西省  2006   4339
# 14        山东省  2006   9309
# 15        河南省  2006   9392
# 16        湖北省  2006   5693
# 17        湖南省  2006   6342
# 18        广东省  2006   9442
# 19    广西壮族自治区  2006   4719
# 20        海南省  2006    836
# 21        重庆市  2006   2808
# 22        四川省  2006   8169
# 23        贵州省  2006   3690
# 24        云南省  2006   4483
# 25      西藏自治区  2006    285
# 26        陕西省  2006   3699
# 27        甘肃省  2006   2547
# 28        青海省  2006    548
# 29    宁夏回族自治区  2006    604
# ..        ...   ...    ...
# 280       天津市  2015   1547
# 281       河北省  2015   7425
# 282       山西省  2015   3664
# 283    内蒙古自治区  2015   2511
# 284       辽宁省  2015   4382
# 285       吉林省  2015   2753
# 286      黑龙江省  2015   3812
# 287       上海市  2015   2415
# 288       江苏省  2015   7976
# 289       浙江省  2015   5539
# 290       安徽省  2015   6144
# 291       福建省  2015   3839
# 292       江西省  2015   4566
# 293       山东省  2015   9847
# 294       河南省  2015   9480
# 295       湖北省  2015   5852
# 296       湖南省  2015   6783
# 297       广东省  2015  10849
# 298   广西壮族自治区  2015   4796
# 299       海南省  2015    911
# 300       重庆市  2015   3017
# 301       四川省  2015   8204
# 302       贵州省  2015   3530
# 303       云南省  2015   4742
# 304     西藏自治区  2015    324
# 305       陕西省  2015   3793
# 306       甘肃省  2015   2600
# 307       青海省  2015    588
# 308   宁夏回族自治区  2015    668
# 309  新疆维吾尔自治区  2015   2360
#
# [310 rows x 3 columns]

# %%
#练习3  连接两个数据
df_p = df_POP_done.join(df_GDP_done,lsuffix='', rsuffix='_GDP')
df_p
# Out:
#            地区     年    POP    地区_GDP 年_GDP       GDP
# 0         北京市  2006   1601       北京市  2006   8117.80
# 1         天津市  2006   1075       天津市  2006   4462.74
# 2         河北省  2006   6898       河北省  2006  11467.60
# 3         山西省  2006   3375       山西省  2006   4878.61
# 4      内蒙古自治区  2006   2415    内蒙古自治区  2006   4944.25
# 5         辽宁省  2006   4271       辽宁省  2006   9304.52
# 6         吉林省  2006   2723       吉林省  2006   4275.12
# 7        黑龙江省  2006   3823      黑龙江省  2006   6211.80
# 8         上海市  2006   1964       上海市  2006  10572.24
# 9         江苏省  2006   7656       江苏省  2006  21742.05
# 10        浙江省  2006   5072       浙江省  2006  15718.47
# 11        安徽省  2006   6110       安徽省  2006   6112.50
# 12        福建省  2006   3585       福建省  2006   7583.85
# 13        江西省  2006   4339       江西省  2006   4820.53
# 14        山东省  2006   9309       山东省  2006  21900.19
# 15        河南省  2006   9392       河南省  2006  12362.79
# 16        湖北省  2006   5693       湖北省  2006   7617.47
# 17        湖南省  2006   6342       湖南省  2006   7688.67
# 18        广东省  2006   9442       广东省  2006  26587.76
# 19    广西壮族自治区  2006   4719   广西壮族自治区  2006   4746.16
# 20        海南省  2006    836       海南省  2006   1065.67
# 21        重庆市  2006   2808       重庆市  2006   3907.23
# 22        四川省  2006   8169       四川省  2006   8690.24
# 23        贵州省  2006   3690       贵州省  2006   2338.98
# 24        云南省  2006   4483       云南省  2006   3988.14
# 25      西藏自治区  2006    285     西藏自治区  2006    290.76
# 26        陕西省  2006   3699       陕西省  2006   4743.61
# 27        甘肃省  2006   2547       甘肃省  2006   2277.35
# 28        青海省  2006    548       青海省  2006    648.50
# 29    宁夏回族自治区  2006    604   宁夏回族自治区  2006    725.90
# ..        ...   ...    ...       ...   ...       ...
# 280       天津市  2015   1547       天津市  2015  16538.19
# 281       河北省  2015   7425       河北省  2015  29806.11
# 282       山西省  2015   3664       山西省  2015  12766.49
# 283    内蒙古自治区  2015   2511    内蒙古自治区  2015  17831.51
# 284       辽宁省  2015   4382       辽宁省  2015  28669.02
# 285       吉林省  2015   2753       吉林省  2015  14063.13
# 286      黑龙江省  2015   3812      黑龙江省  2015  15083.67
# 287       上海市  2015   2415       上海市  2015  25123.45
# 288       江苏省  2015   7976       江苏省  2015  70116.38
# 289       浙江省  2015   5539       浙江省  2015  42886.49
# 290       安徽省  2015   6144       安徽省  2015  22005.63
# 291       福建省  2015   3839       福建省  2015  25979.82
# 292       江西省  2015   4566       江西省  2015  16723.78
# 293       山东省  2015   9847       山东省  2015  63002.33
# 294       河南省  2015   9480       河南省  2015  37002.16
# 295       湖北省  2015   5852       湖北省  2015  29550.19
# 296       湖南省  2015   6783       湖南省  2015  28902.21
# 297       广东省  2015  10849       广东省  2015  72812.55
# 298   广西壮族自治区  2015   4796   广西壮族自治区  2015  16803.12
# 299       海南省  2015    911       海南省  2015   3702.76
# 300       重庆市  2015   3017       重庆市  2015  15717.27
# 301       四川省  2015   8204       四川省  2015  30053.10
# 302       贵州省  2015   3530       贵州省  2015  10502.56
# 303       云南省  2015   4742       云南省  2015  13619.17
# 304     西藏自治区  2015    324     西藏自治区  2015   1026.39
# 305       陕西省  2015   3793       陕西省  2015  18021.86
# 306       甘肃省  2015   2600       甘肃省  2015   6790.32
# 307       青海省  2015    588       青海省  2015   2417.05
# 308   宁夏回族自治区  2015    668   宁夏回族自治区  2015   2911.77
# 309  新疆维吾尔自治区  2015   2360  新疆维吾尔自治区  2015   9324.80
#
# [310 rows x 6 columns]

# %%
df_p.drop(["地区_GDP","年_GDP"], axis=1)
# Out:
#            地区     年    POP       GDP
# 0         北京市  2006   1601   8117.80
# 1         天津市  2006   1075   4462.74
# 2         河北省  2006   6898  11467.60
# 3         山西省  2006   3375   4878.61
# 4      内蒙古自治区  2006   2415   4944.25
# 5         辽宁省  2006   4271   9304.52
# 6         吉林省  2006   2723   4275.12
# 7        黑龙江省  2006   3823   6211.80
# 8         上海市  2006   1964  10572.24
# 9         江苏省  2006   7656  21742.05
# 10        浙江省  2006   5072  15718.47
# 11        安徽省  2006   6110   6112.50
# 12        福建省  2006   3585   7583.85
# 13        江西省  2006   4339   4820.53
# 14        山东省  2006   9309  21900.19
# 15        河南省  2006   9392  12362.79
# 16        湖北省  2006   5693   7617.47
# 17        湖南省  2006   6342   7688.67
# 18        广东省  2006   9442  26587.76
# 19    广西壮族自治区  2006   4719   4746.16
# 20        海南省  2006    836   1065.67
# 21        重庆市  2006   2808   3907.23
# 22        四川省  2006   8169   8690.24
# 23        贵州省  2006   3690   2338.98
# 24        云南省  2006   4483   3988.14
# 25      西藏自治区  2006    285    290.76
# 26        陕西省  2006   3699   4743.61
# 27        甘肃省  2006   2547   2277.35
# 28        青海省  2006    548    648.50
# 29    宁夏回族自治区  2006    604    725.90
# ..        ...   ...    ...       ...
# 280       天津市  2015   1547  16538.19
# 281       河北省  2015   7425  29806.11
# 282       山西省  2015   3664  12766.49
# 283    内蒙古自治区  2015   2511  17831.51
# 284       辽宁省  2015   4382  28669.02
# 285       吉林省  2015   2753  14063.13
# 286      黑龙江省  2015   3812  15083.67
# 287       上海市  2015   2415  25123.45
# 288       江苏省  2015   7976  70116.38
# 289       浙江省  2015   5539  42886.49
# 290       安徽省  2015   6144  22005.63
# 291       福建省  2015   3839  25979.82
# 292       江西省  2015   4566  16723.78
# 293       山东省  2015   9847  63002.33
# 294       河南省  2015   9480  37002.16
# 295       湖北省  2015   5852  29550.19
# 296       湖南省  2015   6783  28902.21
# 297       广东省  2015  10849  72812.55
# 298   广西壮族自治区  2015   4796  16803.12
# 299       海南省  2015    911   3702.76
# 300       重庆市  2015   3017  15717.27
# 301       四川省  2015   8204  30053.10
# 302       贵州省  2015   3530  10502.56
# 303       云南省  2015   4742  13619.17
# 304     西藏自治区  2015    324   1026.39
# 305       陕西省  2015   3793  18021.86
# 306       甘肃省  2015   2600   6790.32
# 307       青海省  2015    588   2417.05
# 308   宁夏回族自治区  2015    668   2911.77
# 309  新疆维吾尔自治区  2015   2360   9324.80
#
# [310 rows x 4 columns]

# %%
df_p.drop(["地区_GDP","年_GDP"], axis=1).set_index(["地区","年"])
# Out:
#                  POP       GDP
# 地区       年
# 北京市      2006   1601   8117.80
# 天津市      2006   1075   4462.74
# 河北省      2006   6898  11467.60
# 山西省      2006   3375   4878.61
# 内蒙古自治区   2006   2415   4944.25
# 辽宁省      2006   4271   9304.52
# 吉林省      2006   2723   4275.12
# 黑龙江省     2006   3823   6211.80
# 上海市      2006   1964  10572.24
# 江苏省      2006   7656  21742.05
# 浙江省      2006   5072  15718.47
# 安徽省      2006   6110   6112.50
# 福建省      2006   3585   7583.85
# 江西省      2006   4339   4820.53
# 山东省      2006   9309  21900.19
# 河南省      2006   9392  12362.79
# 湖北省      2006   5693   7617.47
# 湖南省      2006   6342   7688.67
# 广东省      2006   9442  26587.76
# 广西壮族自治区  2006   4719   4746.16
# 海南省      2006    836   1065.67
# 重庆市      2006   2808   3907.23
# 四川省      2006   8169   8690.24
# 贵州省      2006   3690   2338.98
# 云南省      2006   4483   3988.14
# 西藏自治区    2006    285    290.76
# 陕西省      2006   3699   4743.61
# 甘肃省      2006   2547   2277.35
# 青海省      2006    548    648.50
# 宁夏回族自治区  2006    604    725.90
# ...              ...       ...
# 天津市      2015   1547  16538.19
# 河北省      2015   7425  29806.11
# 山西省      2015   3664  12766.49
# 内蒙古自治区   2015   2511  17831.51
# 辽宁省      2015   4382  28669.02
# 吉林省      2015   2753  14063.13
# 黑龙江省     2015   3812  15083.67
# 上海市      2015   2415  25123.45
# 江苏省      2015   7976  70116.38
# 浙江省      2015   5539  42886.49
# 安徽省      2015   6144  22005.63
# 福建省      2015   3839  25979.82
# 江西省      2015   4566  16723.78
# 山东省      2015   9847  63002.33
# 河南省      2015   9480  37002.16
# 湖北省      2015   5852  29550.19
# 湖南省      2015   6783  28902.21
# 广东省      2015  10849  72812.55
# 广西壮族自治区  2015   4796  16803.12
# 海南省      2015    911   3702.76
# 重庆市      2015   3017  15717.27
# 四川省      2015   8204  30053.10
# 贵州省      2015   3530  10502.56
# 云南省      2015   4742  13619.17
# 西藏自治区    2015    324   1026.39
# 陕西省      2015   3793  18021.86
# 甘肃省      2015   2600   6790.32
# 青海省      2015    588   2417.05
# 宁夏回族自治区  2015    668   2911.77
# 新疆维吾尔自治区 2015   2360   9324.80
#
# [310 rows x 2 columns]

# %%
df_pp = df_p.drop(["地区_GDP","年_GDP"], axis=1).set_index(["地区","年"])

# %%
df_pp.query("年==2015")
# Out:
#                  POP       GDP
# 地区       年
# 北京市      2015   2171  23014.59
# 天津市      2015   1547  16538.19
# 河北省      2015   7425  29806.11
# 山西省      2015   3664  12766.49
# 内蒙古自治区   2015   2511  17831.51
# 辽宁省      2015   4382  28669.02
# 吉林省      2015   2753  14063.13
# 黑龙江省     2015   3812  15083.67
# 上海市      2015   2415  25123.45
# 江苏省      2015   7976  70116.38
# 浙江省      2015   5539  42886.49
# 安徽省      2015   6144  22005.63
# 福建省      2015   3839  25979.82
# 江西省      2015   4566  16723.78
# 山东省      2015   9847  63002.33
# 河南省      2015   9480  37002.16
# 湖北省      2015   5852  29550.19
# 湖南省      2015   6783  28902.21
# 广东省      2015  10849  72812.55
# 广西壮族自治区  2015   4796  16803.12
# 海南省      2015    911   3702.76
# 重庆市      2015   3017  15717.27
# 四川省      2015   8204  30053.10
# 贵州省      2015   3530  10502.56
# 云南省      2015   4742  13619.17
# 西藏自治区    2015    324   1026.39
# 陕西省      2015   3793  18021.86
# 甘肃省      2015   2600   6790.32
# 青海省      2015    588   2417.05
# 宁夏回族自治区  2015    668   2911.77
# 新疆维吾尔自治区 2015   2360   9324.80

# %%
#可视化 使用pands 自带的plot来制图
# %matplotlib inline
df_pp.query("年==2015").plot(kind='scatter', x='POP', y='GDP', 
          title = 'POP与GDP的关系：分省数据')

# %%
#解决中文乱码问题
import matplotlib as mpl
import matplotlib.pyplot as plt
import pylab
mpl.rcParams['font.sans-serif']=['SimHei']
mpl.rcParams['axes.unicode_minus']=False

df_plot = df_pp.query("年==2015")
df_plot.plot(kind='scatter', x='POP', y='GDP', 
          title = 'POP与GDP的关系：分省数据')

# %%
#练习5  用 numpy.polyfit 做线性回归
import numpy as np
fit = np.polyfit(x=df_pp.query("年==2015")['POP'], y=df_pp.query("年==2015")['GDP'], deg=1)

# %%
x=df_plot['POP']
y=df_plot['GDP']
ax = df_plot.plot(kind='scatter', x='POP', y='GDP', 
          title = 'POP与GDP的关系：分省数据')
ax.plot(x, fit[0] * x + fit[1], color='red')
ax.scatter(x, y)

# %%
#练习6  可视化 使用bokeh 来制图，可交互（HoverTool tooltip）
df_pp
# Out:
#                  POP       GDP
# 地区       年
# 北京市      2006   1601   8117.80
# 天津市      2006   1075   4462.74
# 河北省      2006   6898  11467.60
# 山西省      2006   3375   4878.61
# 内蒙古自治区   2006   2415   4944.25
# 辽宁省      2006   4271   9304.52
# 吉林省      2006   2723   4275.12
# 黑龙江省     2006   3823   6211.80
# 上海市      2006   1964  10572.24
# 江苏省      2006   7656  21742.05
# 浙江省      2006   5072  15718.47
# 安徽省      2006   6110   6112.50
# 福建省      2006   3585   7583.85
# 江西省      2006   4339   4820.53
# 山东省      2006   9309  21900.19
# 河南省      2006   9392  12362.79
# 湖北省      2006   5693   7617.47
# 湖南省      2006   6342   7688.67
# 广东省      2006   9442  26587.76
# 广西壮族自治区  2006   4719   4746.16
# 海南省      2006    836   1065.67
# 重庆市      2006   2808   3907.23
# 四川省      2006   8169   8690.24
# 贵州省      2006   3690   2338.98
# 云南省      2006   4483   3988.14
# 西藏自治区    2006    285    290.76
# 陕西省      2006   3699   4743.61
# 甘肃省      2006   2547   2277.35
# 青海省      2006    548    648.50
# 宁夏回族自治区  2006    604    725.90
# ...              ...       ...
# 天津市      2015   1547  16538.19
# 河北省      2015   7425  29806.11
# 山西省      2015   3664  12766.49
# 内蒙古自治区   2015   2511  17831.51
# 辽宁省      2015   4382  28669.02
# 吉林省      2015   2753  14063.13
# 黑龙江省     2015   3812  15083.67
# 上海市      2015   2415  25123.45
# 江苏省      2015   7976  70116.38
# 浙江省      2015   5539  42886.49
# 安徽省      2015   6144  22005.63
# 福建省      2015   3839  25979.82
# 江西省      2015   4566  16723.78
# 山东省      2015   9847  63002.33
# 河南省      2015   9480  37002.16
# 湖北省      2015   5852  29550.19
# 湖南省      2015   6783  28902.21
# 广东省      2015  10849  72812.55
# 广西壮族自治区  2015   4796  16803.12
# 海南省      2015    911   3702.76
# 重庆市      2015   3017  15717.27
# 四川省      2015   8204  30053.10
# 贵州省      2015   3530  10502.56
# 云南省      2015   4742  13619.17
# 西藏自治区    2015    324   1026.39
# 陕西省      2015   3793  18021.86
# 甘肃省      2015   2600   6790.32
# 青海省      2015    588   2417.05
# 宁夏回族自治区  2015    668   2911.77
# 新疆维吾尔自治区 2015   2360   9324.80
#
# [310 rows x 2 columns]

# %%
df_pp['desc'] = df_pp.index.get_level_values(0)# tooltip 工具提示

# %%
#制图
from bokeh.plotting import figure, output_file, show, output_notebook
from bokeh.models import HoverTool, BoxSelectTool

title = '分省数据' 
xlabel = 'POP：人口' 
ylabel = 'GDP：产值'

hover = HoverTool(
    tooltips=[
        ( '人口',  '$x{0,F}'), 
        ( '产值',  '$y{0,F}'),
        ( '地区',  '@desc'  ),
    ]
)

TOOLS = [hover, "pan, wheel_zoom, box_zoom, reset, resize"]
fig = figure(plot_width=800, plot_height=600,
           x_axis_label = xlabel, y_axis_label = ylabel, 
           title=title, tools=TOOLS)

df_plot = df_pp.query("年==2015")

fig.circle("POP", "GDP",
         source = df_plot,
         fill_alpha=0.6, line_color=None, size= 30)

#regression line
xs = [min(df_plot["POP"]), max(df_plot["POP"])]
fig.line(x=xs, y=[ fit[0] * x + fit[1] for x in xs] )

output_notebook() # 输出到IPython/Jupyter Notebook，若要输出到他处需调整
#output_file('by_provinces.htm') # 输出到 htm
show(fig)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ebd34bc9-e679-474c-a4df-462b8bff85d5">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6b24da3f-fa8f-4fa6-a402-1bfa5170e0bb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("6b24da3f-fa8f-4fa6-a402-1bfa5170e0bb").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6b24da3f-fa8f-4fa6-a402-1bfa5170e0bb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6b24da3f-fa8f-4fa6-a402-1bfa5170e0bb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1e12cf84-8baa-4938-b8f0-f5779a612a02":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[324,10849],"y":[867.6294903625625,58517.310071751344]}},"id":"ec338ccf-6a20-414e-8b63-723dd82043d3","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"e9dbe4ff-7c00-40d6-9a62-6055127e5ba3","type":"DataRange1d"},{"attributes":{},"id":"e9017b93-39d1-45ae-9182-6bbeb503cf08","type":"BasicTicker"},{"attributes":{"plot":{"id":"86c036d7-b524-4243-8e30-e0441f14ac3d","subtype":"Figure","type":"Plot"},"ticker":{"id":"e9017b93-39d1-45ae-9182-6bbeb503cf08","type":"BasicTicker"}},"id":"cf5d71f1-c282-4675-9005-c2b6698564ff","type":"Grid"},{"attributes":{},"id":"d5673baa-bcf1-4052-b3d0-f9170f342b98","type":"ToolEvents"},{"attributes":{"axis_label":"GDP\uff1a\u4ea7\u503c","formatter":{"id":"082a8ba3-dfa8-4635-a932-f49fb853d29e","type":"BasicTickFormatter"},"plot":{"id":"86c036d7-b524-4243-8e30-e0441f14ac3d","subtype":"Figure","type":"Plot"},"ticker":{"id":"4d51a436-8b78-42c4-86d3-0797a236e862","type":"BasicTicker"}},"id":"a43242a0-3a77-4ee2-a7c1-2fb92806d9f5","type":"LinearAxis"},{"attributes":{},"id":"4d51a436-8b78-42c4-86d3-0797a236e862","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"86c036d7-b524-4243-8e30-e0441f14ac3d","subtype":"Figure","type":"Plot"},"ticker":{"id":"4d51a436-8b78-42c4-86d3-0797a236e862","type":"BasicTicker"}},"id":"8fcc3e6a-3835-4612-b283-d4084c20cc72","type":"Grid"},{"attributes":{"plot":{"id":"86c036d7-b524-4243-8e30-e0441f14ac3d","subtype":"Figure","type":"Plot"}},"id":"7f3339e0-852f-40a2-8279-db75edd6d2fd","type":"PanTool"},{"attributes":{"callback":null,"column_names":["POP","GDP","desc","\u5730\u533a_\u5e74"],"data":{"GDP":[23014.59,16538.19,29806.11,12766.49,17831.51,28669.02,14063.13,15083.67,25123.45,70116.38,42886.49,22005.63,25979.82,16723.78,63002.33,37002.16,29550.19,28902.21,72812.55,16803.12,3702.76,15717.27,30053.1,10502.56,13619.17,1026.39,18021.86,6790.32,2417.05,2911.77,9324.8],"POP":[2171,1547,7425,3664,2511,4382,2753,3812,2415,7976,5539,6144,3839,4566,9847,9480,5852,6783,10849,4796,911,3017,8204,3530,4742,324,3793,2600,588,668,2360],"desc":["\u5317\u4eac\u5e02","\u5929\u6d25\u5e02","\u6cb3\u5317\u7701","\u5c71\u897f\u7701","\u5185\u8499\u53e4\u81ea\u6cbb\u533a","\u8fbd\u5b81\u7701","\u5409\u6797\u7701","\u9ed1\u9f99\u6c5f\u7701","\u4e0a\u6d77\u5e02","\u6c5f\u82cf\u7701","\u6d59\u6c5f\u7701","\u5b89\u5fbd\u7701","\u798f\u5efa\u7701","\u6c5f\u897f\u7701","\u5c71\u4e1c\u7701","\u6cb3\u5357\u7701","\u6e56\u5317\u7701","\u6e56\u5357\u7701","\u5e7f\u4e1c\u7701","\u5e7f\u897f\u58ee\u65cf\u81ea\u6cbb\u533a","\u6d77\u5357\u7701","\u91cd\u5e86\u5e02","\u56db\u5ddd\u7701","\u8d35\u5dde\u7701","\u4e91\u5357\u7701","\u897f\u85cf\u81ea\u6cbb\u533a","\u9655\u897f\u7701","\u7518\u8083\u7701","\u9752\u6d77\u7701","\u5b81\u590f\u56de\u65cf\u81ea\u6cbb\u533a","\u65b0\u7586\u7ef4\u543e\u5c14\u81ea\u6cbb\u533a"],"\u5730\u533a_\u5e74":[["\u5317\u4eac\u5e02",2015],["\u5929\u6d25\u5e02",2015],["\u6cb3\u5317\u7701",2015],["\u5c71\u897f\u7701",2015],["\u5185\u8499\u53e4\u81ea\u6cbb\u533a",2015],["\u8fbd\u5b81\u7701",2015],["\u5409\u6797\u7701",2015],["\u9ed1\u9f99\u6c5f\u7701",2015],["\u4e0a\u6d77\u5e02",2015],["\u6c5f\u82cf\u7701",2015],["\u6d59\u6c5f\u7701",2015],["\u5b89\u5fbd\u7701",2015],["\u798f\u5efa\u7701",2015],["\u6c5f\u897f\u7701",2015],["\u5c71\u4e1c\u7701",2015],["\u6cb3\u5357\u7701",2015],["\u6e56\u5317\u7701",2015],["\u6e56\u5357\u7701",2015],["\u5e7f\u4e1c\u7701",2015],["\u5e7f\u897f\u58ee\u65cf\u81ea\u6cbb\u533a",2015],["\u6d77\u5357\u7701",2015],["\u91cd\u5e86\u5e02",2015],["\u56db\u5ddd\u7701",2015],["\u8d35\u5dde\u7701",2015],["\u4e91\u5357\u7701",2015],["\u897f\u85cf\u81ea\u6cbb\u533a",2015],["\u9655\u897f\u7701",2015],["\u7518\u8083\u7701",2015],["\u9752\u6d77\u7701",2015],["\u5b81\u590f\u56de\u65cf\u81ea\u6cbb\u533a",2015],["\u65b0\u7586\u7ef4\u543e\u5c14\u81ea\u6cbb\u533a",2015]]}},"id":"d75a0fc3-ef0e-4893-8ee4- ...

# %%
#练习7  可视化 使用bokeh 来制图，可交互（slider）
from bokeh.plotting import figure
from bokeh.io import output_notebook, push_notebook, show
from bokeh.models import CustomJS, Slider,HoverTool, BoxSelectTool
from bokeh.layouts import column

title = '分省数据' 
xlabel = 'POP：人口大小' 
ylabel = 'GDP：产值大小'
hover = HoverTool(
    tooltips=[
        ( '人口大小',  '$x{0,F}'), 
        ( '产值大小',  '$y{0,F}'),
        ( '地区',  '@desc'  ),
    ]
)

TOOLS = [hover, "pan, wheel_zoom, box_zoom, reset, resize"]

fig = figure(plot_width=800, plot_height=600,
           x_axis_label = xlabel, y_axis_label = ylabel, 
           title=title, tools=TOOLS)

yr_min = df_pp.index.get_level_values(1).min()
df_plot = df_pp.query("年=={yr}".format(yr=yr_min))
plt = fig.circle("POP", "GDP",
         source = df_plot,
         fill_alpha=0.6, line_color=None, size= 15)


def update_plot(year):
    #plt.data_source.data = df_pp.query("年=={yr}".format(yr=year))
    plt.data_source.data['POP'] = list(df_pp.query("年=={yr}".format(yr=year)).loc[:,['POP']].iloc[:,0].values)
    plt.data_source.data['GDP'] = list(df_pp.query("年=={yr}".format(yr=year)).loc[:,['GDP']].iloc[:,0].values)
    plt.data_source.data['地区_年'] = [(x[0],int(year)) for x in plt.data_source.data['地区_年']]

    push_notebook(handle=bokeh_handle)  
    print (year)
    ##### new notebook cell #####

callback = CustomJS(code="""
if (IPython.notebook.kernel !== undefined) {
    var kernel = IPython.notebook.kernel;
    cmd = "update_plot(" + cb_obj.value + ")";
    kernel.execute(cmd, {}, {});
}
""")

slider = Slider(start=df_pp.index.get_level_values(1).min(), 
                end=df_pp.index.get_level_values(1).max(),
                value=1,
                step=1,
                title="年",
                callback=callback)
output_notebook()

bokeh_handle = show(column(slider, fig), notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b68e073f-3c65-417d-a77f-f385fce51083">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="42a51cee-6d69-4253-8d71-589bd4946114"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("42a51cee-6d69-4253-8d71-589bd4946114").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("2928dcee-6686-4254-87d9-a607a2934dd5", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("42a51cee-6d69-4253-8d71-589bd4946114");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '42a51cee-6d69-4253-8d71-589bd4946114' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5336be3d-a301-42b3-964a-6139846a3cb3":{"roots":{"references":[{"attributes":{"children":[{"id":"5515666e-ce23-43c9-b9d8-55e4156c17f8","type":"Slider"}]},"id":"058ed32c-881e-4881-a17b-e04341787521","type":"WidgetBox"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":15},"x":{"field":"POP"},"y":{"field":"GDP"}},"id":"750c3ab1-b4ee-4c89-9af6-2edb801c0aee","type":"Circle"},{"attributes":{"callback":null,"plot":{"id":"dc31b046-2704-4b8c-a80f-7d11306b57b7","subtype":"Figure","type":"Plot"},"tooltips":[["\u4eba\u53e3\u5927\u5c0f","$x{0,F}"],["\u4ea7\u503c\u5927\u5c0f","$y{0,F}"],["\u5730\u533a","@desc"]]},"id":"2823242e-be41-42fd-bccf-39dbafbe94f4","type":"HoverTool"},{"attributes":{"data_source":{"id":"cfb03111-71e7-40fa-a98c-c82d5971d734","type":"ColumnDataSource"},"glyph":{"id":"062eb900-ae1d-467f-a149-d852662d1b41","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"750c3ab1-b4ee-4c89-9af6-2edb801c0aee","type":"Circle"},"selection_glyph":null},"id":"da5c53ae-2590-414e-8874-fa0de92ea986","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":"\u5206\u7701\u6570\u636e"},"id":"e4705c5a-623b-4129-881c-c5b747cb9092","type":"Title"},{"attributes":{"below":[{"id":"d08907ff-c9f3-4367-bafe-c703e34439d0","type":"LinearAxis"}],"left":[{"id":"88fe58d4-9113-4c5e-ad4e-a86c271d65f0","type":"LinearAxis"}],"plot_width":800,"renderers":[{"id":"d08907ff-c9f3-4367-bafe-c703e34439d0","type":"LinearAxis"},{"id":"b57215de-5b10-4f18-9239-3d10cadf12e6","type":"Grid"},{"id":"88fe58d4-9113-4c5e-ad4e-a86c271d65f0","type":"LinearAxis"},{"id":"03babd60-3bb1-4e2f-807b-81ca21f86f15","type":"Grid"},{"id":"223ab0d3-71a5-445a-9cd9-c2c173cea7d5","type":"BoxAnnotation"},{"id":"da5c53ae-2590-414e-8874-fa0de92ea986","type":"GlyphRenderer"}],"title":{"id":"e4705c5a-623b-4129-881c-c5b747cb9092","type":"Title"},"tool_events":{"id":"6bc87eef-8462-4c37-a28c-9dd94faf39c7","type":"ToolEvents"},"toolbar":{"id":"1a38fd85-53bc-49be-928f-8349ac903056","type":"Toolbar"},"x_range":{"id":"bdbae71c-12e9-4096-a24d-1b8e928d37c0","type":"DataRange1d"},"y_range":{"id":"e3492afc-f197-47dd-b923-6df95babb74c","type":"DataRange1d"}},"id":"dc31b046-2704-4b8c-a80f-7d11306b57b7","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null},"id":"bdbae71c-12e9-4096-a24d-1b8e928d37c0","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"value":"#1f77b4"},"line_color":{"value":null},"size":{"units":"screen","value":15},"x":{"field":"POP"},"y":{"field":"GDP"}},"id":"062eb900-ae1d-467f-a149-d852662d1b41","type":"Circle"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2823242e-be41-42fd-bccf-39dbafbe94f4","type":"HoverTool"},{"id":"3b27b046-3931-4f11-9285-9be9012347ae","type":"PanTool"},{"id":"2b0d5365-166f-4a19-930f-6b019e9f4c73","type":"WheelZoomTool"},{"id":"a74811ce-dbc7-4e52-86b4-303f802e4964","type":"BoxZoomTool"},{"id":"cb947342-d5fa-4bfa-9f4d-b2bc9b6a29fb","type":"ResetTool"},{"id":"b3fcaaa8-0257-4a83-b2d9-faaad4e30dc6","type":"ResizeTool"}]},"id":"1a38fd85-53bc-49be-928f-8349ac903056","type":"Toolbar"},{"attributes":{"axis_label":"POP\uff1a\u4eba\u53e3\u5927\u5c0f","formatter":{"id":"f900a5df-ea47-4e6d-8883-0b6e687eb7ec","type":"BasicTickFormatter"},"plot":{"id":"dc31b046-2704-4b8c-a80f-7d11306b57b7","subtype":"Figure","type":"Plot"},"ticker":{"id":"548ac16b-3bb3-465f-98ce-90fba55dac11","type":"BasicTicker"}},"id":"d08907ff-c9f3-4367-bafe-c703e34439d0","type":"LinearAxis"},{"attributes":{},"id":"6bc87eef-8462-4c37-a28c-9dd94faf39c7","type":"ToolEvents"},{"attributes":{"children":[{"id":"058ed32c-881e-4881-a17b-e04341787521","type":"WidgetBox"},{"id":"dc31b046-2704-4b8c-a80f-7d11306b57b7","subtype":"Figure","type":"Plot"}]},"id":"f0828131-091f-4135-80e5-7267e9f6a72e","type":"Column"},{"attributes":{"callback":null},"id":"e3492afc-f197-47dd-b923-6df95babb ...

# %%
yr = 2015
df_plot = df_pp.query("年=={yr}".format(yr=yr_min))
# Regression Using Pandas and Statsmodels
fit = np.polyfit(x=df_plot['POP'], 
                 y=df_plot['GDP'], deg=1)

# %%
df_plot['expected'] =  [ fit[0] * x + fit[1] for x in df_plot['POP']] 
df_plot['difference'] =  df_plot['GDP'] - df_plot['expected']
df_plot['difference_ratio'] = ( df_plot['GDP'] - df_plot['expected'] ) /df_plot['POP']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
df_plot.sort_values(by='difference_ratio')
# Out:
#                 POP       GDP      desc      expected   difference  \
# 地区       年
# 贵州省      2006  3690   2338.98       贵州省   6602.713277 -4263.733277
# 云南省      2006  4483   3988.14       云南省   8077.969353 -4089.829353
# 甘肃省      2006  2547   2277.35       甘肃省   4476.335352 -2198.985352
# 安徽省      2006  6110   6112.50       安徽省  11104.755777 -4992.255777
# 广西壮族自治区  2006  4719   4746.16   广西壮族自治区   8517.011514 -3770.851514
# 四川省      2006  8169   8690.24       四川省  14935.212599 -6244.972599
# 江西省      2006  4339   4820.53       江西省   7810.079220 -2989.549220
# 湖南省      2006  6342   7688.67       湖南省  11536.356546 -3847.686546
# 河南省      2006  9392  12362.79       河南省  17210.418375 -4847.628375
# 陕西省      2006  3699   4743.61       陕西省   6619.456410 -1875.846410
# 湖北省      2006  5693   7617.47       湖北省  10328.990603 -2711.520603
# 重庆市      2006  2808   3907.23       重庆市   4961.886217 -1054.656217
# 山西省      2006  3375   4878.61       山西省   6016.703613 -1138.093613
# 海南省      2006   836   1065.67       海南省   1293.279684  -227.609684
# 新疆维吾尔自治区 2006  2050   3045.26  新疆维吾尔自治区   3551.742326  -506.482326
# 宁夏回族自治区  2006   604    725.90   宁夏回族自治区    861.678915  -135.778915
# 青海省      2006   548    648.50       青海省    757.499419  -108.999419
# 吉林省      2006  2723   4275.12       吉林省   4803.756625  -528.636625
# 黑龙江省     2006  3823   6211.80      黑龙江省   6850.139580  -638.339580
# 河北省      2006  6898  11467.60       河北省  12570.710112 -1103.110112
# 西藏自治区    2006   285    290.76     西藏自治区    268.227858    22.532142
# 内蒙古自治区   2006  2415   4944.25    内蒙古自治区   4230.769398   713.480602
# 福建省      2006  3585   7583.85       福建省   6407.376722  1176.473278
# 辽宁省      2006  4271   9304.52       辽宁省   7683.575547  1620.944453
# 山东省      2006  9309  21900.19       山东省  17056.009479  4844.180521
# 广东省      2006  9442  26587.76       广东省  17303.435782  9284.324218
# 江苏省      2006  7656  21742.05       江苏省  13980.854003  7761.195997
# 浙江省      2006  5072  15718.47       浙江省   9173.714407  6544.755593
# 天津市      2006  1075   4462.74       天津市   1737.902889  2724.837111
# 北京市      2006  1601   8117.80       北京市   2716.446011  5401.353989
# 上海市      2006  1964  10572.24       上海市   3391.752386  7180.487614
#
#                difference_ratio
# 地区       年
# 贵州省      2006         -1.155483
# 云南省      2006         -0.912297
# 甘肃省      2006         -0.863363
# 安徽省      2006         -0.817063
# 广西壮族自治区  2006         -0.799079
# 四川省      2006         -0.764472
# 江西省      2006         -0.688995
# 湖南省      2006         -0.606699
# 河南省      2006         -0.516144
# 陕西省      2006         -0.507123
# 湖北省      2006         -0.476290
# 重庆市      2006         -0.375590
# 山西省      2006         -0.337213
# 海南省      2006         -0.272260
# 新疆维吾尔自治区 2006         -0.247065
# 宁夏回族自治区  2006         -0.224800
# 青海省      2006         -0.198904
# 吉林省      2006         -0.194138
# 黑龙江省     2006         -0.166973
# 河北省      2006         -0.159917
# 西藏自治区    2006          0.079060
# 内蒙古自治区   2006          0.295437
# 福建省      2006          0.328165
# 辽宁省      2006          0.379523
# 山东省      2006          0.520376
# 广东省      2006          0.983301
# 江苏省      2006          1.013740
# 浙江省      2006          1.290370
# 天津市      2006          2.534732
# 北京市      2006          3.373738
# 上海市      2006          3.656053

# %%
df_plot.sort_values(by='difference_ratio')[['difference_ratio']]
# Out:
#                difference_ratio
# 地区       年
# 贵州省      2006         -1.155483
# 云南省      2006         -0.912297
# 甘肃省      2006         -0.863363
# 安徽省      2006         -0.817063
# 广西壮族自治区  2006         -0.799079
# 四川省      2006         -0.764472
# 江西省      2006         -0.688995
# 湖南省      2006         -0.606699
# 河南省      2006         -0.516144
# 陕西省      2006         -0.507123
# 湖北省      2006         -0.476290
# 重庆市      2006         -0.375590
# 山西省      2006         -0.337213
# 海南省      2006         -0.272260
# 新疆维吾尔自治区 2006         -0.247065
# 宁夏回族自治区  2006         -0.224800
# 青海省      2006         -0.198904
# 吉林省      2006         -0.194138
# 黑龙江省     2006         -0.166973
# 河北省      2006         -0.159917
# 西藏自治区    2006          0.079060
# 内蒙古自治区   2006          0.295437
# 福建省      2006          0.328165
# 辽宁省      2006          0.379523
# 山东省      2006          0.520376
# 广东省      2006          0.983301
# 江苏省      2006          1.013740
# 浙江省      2006          1.290370
# 天津市      2006          2.534732
# 北京市      2006          3.373738
# 上海市      2006          3.656053

# %%
df_output = df_plot.sort_values(by='difference_ratio')[['difference_ratio']]
df_output.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th></th>\n      <th>difference_ratio</th>\n    </tr>\n    <tr>\n      <th>地区</th>\n      <th>年</th>\n      <th></th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>贵州省</th>\n      <th>2006</th>\n      <td>-1.155483</td>\n    </tr>\n    <tr>\n      <th>云南省</th>\n      <th>2006</th>\n      <td>-0.912297</td>\n    </tr>\n    <tr>\n      <th>甘肃省</th>\n      <th>2006</th>\n      <td>-0.863363</td>\n    </tr>\n    <tr>\n      <th>安徽省</th>\n      <th>2006</th>\n      <td>-0.817063</td>\n    </tr>\n    <tr>\n      <th>广西壮族自治区</th>\n      <th>2006</th>\n      <td>-0.799079</td>\n    </tr>\n    <tr>\n      <th>四川省</th>\n      <th>2006</th>\n      <td>-0.764472</td>\n    </tr>\n    <tr>\n      <th>江西省</th>\n      <th>2006</th>\n      <td>-0.688995</td>\n    </tr>\n    <tr>\n      <th>湖南省</th>\n      <th>2006</th>\n      <td>-0.606699</td>\n    </tr>\n    <tr>\n      <th>河南省</th>\n      <th>2006</th>\n      <td>-0.516144</td>\n    </tr>\n    <tr>\n      <th>陕西省</th>\n      <th>2006</th>\n      <td>-0.507123</td>\n    </tr>\n    <tr>\n      <th>湖北省</th>\n      <th>2006</th>\n      <td>-0.476290</td>\n    </tr>\n    <tr>\n      <th>重庆市</th>\n      <th>2006</th>\n      <td>-0.375590</td>\n    </tr>\n    <tr>\n      <th>山西省</th>\n      <th>2006</th>\n      <td>-0.337213</td>\n    </tr>\n    <tr>\n      <th>海南省</th>\n      <th>2006</th>\n      <td>-0.272260</td>\n    </tr>\n    <tr>\n      <th>新疆维吾尔自治区</th>\n      <th>2006</th>\n      <td>-0.247065</td>\n    </tr>\n    <tr>\n      <th>宁夏回族自治区</th>\n      <th>2006</th>\n      <td>-0.224800</td>\n    </tr>\n    <tr>\n      <th>青海省</th>\n      <th>2006</th>\n      <td>-0.198904</td>\n    </tr>\n    <tr>\n      <th>吉林省</th>\n      <th>2006</th>\n      <td>-0.194138</td>\n    </tr>\n    <tr>\n      <th>黑龙江省</th>\n      <th>2006</th>\n      <td>-0.166973</td>\n    </tr>\n    <tr>\n      <th>河北省</th>\n      <th>2006</th>\n      <td>-0.159917</td>\n    </tr>\n    <tr>\n      <th>西藏自治区</th>\n      <th>2006</th>\n      <td>0.079060</td>\n    </tr>\n    <tr>\n      <th>内蒙古自治区</th>\n      <th>2006</th>\n      <td>0.295437</td>\n    </tr>\n    <tr>\n      <th>福建省</th>\n      <th>2006</th>\n      <td>0.328165</td>\n    </tr>\n    <tr>\n      <th>辽宁省</th>\n      <th>2006</th>\n      <td>0.379523</td>\n    </tr>\n    <tr>\n      <th>山东省</th>\n      <th>2006</th>\n      <td>0.520376</td>\n    </tr>\n    <tr>\n      <th>广东省</th>\n      <th>2006</th>\n      <td>0.983301</td>\n    </tr>\n    <tr>\n      <th>江苏省</th>\n      <th>2006</th>\n      <td>1.013740</td>\n    </tr>\n    <tr>\n      <th>浙江省</th>\n      <th>2006</th>\n      <td>1.290370</td>\n    </tr>\n    <tr>\n      <th>天津市</th>\n      <th>2006</th>\n      <td>2.534732</td>\n    </tr>\n    <tr>\n      <th>北京市</th>\n      <th>2006</th>\n      <td>3.373738</td>\n    </tr>\n    <tr>\n      <th>上海市</th>\n      <th>2006</th>\n      <td>3.656053</td>\n    </tr>\n  </tbody>\n</table>'

# %%
with open("table.htm", "w", encoding="utf8") as fp:
    fp.write

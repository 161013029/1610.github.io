# %%
import pandas as pd

# %%
import glob
print(glob.glob("*.csv"))
# Out:
# ['GDP.csv', 'HP.csv']

# %%
df_try = pd.read_table("GDP.csv",   
                       encoding = 'utf8',        
                      )

# %%
df_try
# Out:
#                                  数据库：分省年度数据,,,,,,,,,,
# 0                             指标：地区生产总值(亿元),,,,,,,,,,
# 1                                  时间：最近10年,,,,,,,,,,
# 2   地区,2015年,2014年,2013年,2012年,2011年,2010年,2009年,2...
# 3   北京市,23014.59,21330.83,19800.81,17879.4,16251.9...
# 4   天津市,16538.19,15726.93,14442.01,12893.88,11307....
# 5   河北省,29806.11,29421.15,28442.95,26575.01,24515....
# 6   山西省,12766.49,12761.49,12665.25,12112.83,11237....
# 7   内蒙古自治区,17831.51,17770.19,16916.5,15880.58,1435...
# 8   辽宁省,28669.02,28626.58,27213.22,24846.43,22226....
# 9   吉林省,14063.13,13803.14,13046.4,11939.24,10568.8...
# 10  黑龙江省,15083.67,15039.38,14454.91,13691.58,12582...
# 11  上海市,25123.45,23567.7,21818.15,20181.72,19195.6...
# 12  江苏省,70116.38,65088.32,59753.37,54058.22,49110....
# 13  浙江省,42886.49,40173.03,37756.59,34665.33,32318....
# 14  安徽省,22005.63,20848.75,19229.34,17212.05,15300....
# 15  福建省,25979.82,24055.76,21868.49,19701.78,17560....
# 16  江西省,16723.78,15714.63,14410.19,12948.88,11702....
# 17  山东省,63002.33,59426.59,55230.32,50013.24,45361....
# 18  河南省,37002.16,34938.24,32191.3,29599.31,26931.0...
# 19  湖北省,29550.19,27379.22,24791.83,22250.45,19632....
# 20  湖南省,28902.21,27037.32,24621.67,22154.23,19669....
# 21  广东省,72812.55,67809.85,62474.79,57067.92,53210....
# 22  广西壮族自治区,16803.12,15672.89,14449.9,13035.1,1172...
# 23  海南省,3702.76,3500.72,3177.56,2855.54,2522.66,20...
# 24  重庆市,15717.27,14262.6,12783.26,11409.6,10011.37...
# 25  四川省,30053.1,28536.66,26392.07,23872.8,21026.68...
# 26  贵州省,10502.56,9266.39,8086.86,6852.2,5701.84,46...
# 27  云南省,13619.17,12814.59,11832.31,10309.47,8893.1...
# 28  西藏自治区,1026.39,920.83,815.67,701.03,605.83,507....
# 29  陕西省,18021.86,17689.94,16205.45,14453.68,12512....
# 30  甘肃省,6790.32,6836.82,6330.69,5650.2,5020.37,412...
# 31  青海省,2417.05,2303.32,2122.06,1893.54,1670.44,13...
# 32  宁夏回族自治区,2911.77,2752.1,2577.57,2341.29,2102.21...
# 33  新疆维吾尔自治区,9324.8,9273.46,8443.84,7505.31,6610.0...

# %%
df    = pd.read_table("GDP.csv",   # 档名
                       encoding = 'utf8',       # 编码
                       header = 3               # 指定数据的标题为原始数据之第3行
                     )
df
# Out:
#    地区,2015年,2014年,2013年,2012年,2011年,2010年,2009年,2008年,2007年,2006年
# 0   北京市,23014.59,21330.83,19800.81,17879.4,16251.9...
# 1   天津市,16538.19,15726.93,14442.01,12893.88,11307....
# 2   河北省,29806.11,29421.15,28442.95,26575.01,24515....
# 3   山西省,12766.49,12761.49,12665.25,12112.83,11237....
# 4   内蒙古自治区,17831.51,17770.19,16916.5,15880.58,1435...
# 5   辽宁省,28669.02,28626.58,27213.22,24846.43,22226....
# 6   吉林省,14063.13,13803.14,13046.4,11939.24,10568.8...
# 7   黑龙江省,15083.67,15039.38,14454.91,13691.58,12582...
# 8   上海市,25123.45,23567.7,21818.15,20181.72,19195.6...
# 9   江苏省,70116.38,65088.32,59753.37,54058.22,49110....
# 10  浙江省,42886.49,40173.03,37756.59,34665.33,32318....
# 11  安徽省,22005.63,20848.75,19229.34,17212.05,15300....
# 12  福建省,25979.82,24055.76,21868.49,19701.78,17560....
# 13  江西省,16723.78,15714.63,14410.19,12948.88,11702....
# 14  山东省,63002.33,59426.59,55230.32,50013.24,45361....
# 15  河南省,37002.16,34938.24,32191.3,29599.31,26931.0...
# 16  湖北省,29550.19,27379.22,24791.83,22250.45,19632....
# 17  湖南省,28902.21,27037.32,24621.67,22154.23,19669....
# 18  广东省,72812.55,67809.85,62474.79,57067.92,53210....
# 19  广西壮族自治区,16803.12,15672.89,14449.9,13035.1,1172...
# 20  海南省,3702.76,3500.72,3177.56,2855.54,2522.66,20...
# 21  重庆市,15717.27,14262.6,12783.26,11409.6,10011.37...
# 22  四川省,30053.1,28536.66,26392.07,23872.8,21026.68...
# 23  贵州省,10502.56,9266.39,8086.86,6852.2,5701.84,46...
# 24  云南省,13619.17,12814.59,11832.31,10309.47,8893.1...
# 25  西藏自治区,1026.39,920.83,815.67,701.03,605.83,507....
# 26  陕西省,18021.86,17689.94,16205.45,14453.68,12512....
# 27  甘肃省,6790.32,6836.82,6330.69,5650.2,5020.37,412...
# 28  青海省,2417.05,2303.32,2122.06,1893.54,1670.44,13...
# 29  宁夏回族自治区,2911.77,2752.1,2577.57,2341.29,2102.21...
# 30  新疆维吾尔自治区,9324.8,9273.46,8443.84,7505.31,6610.0...

# %%
df    = pd.read_table("GDP.csv",   # 档名
                       encoding = 'utf8',       # 编码
                       header = 3,              # 指定数据的标题为原始数据之第3行
                       skiprows = [35,36]       # 原始数据之第35, 36行跳过不计
                     )
df
# Out:
#    地区,2015年,2014年,2013年,2012年,2011年,2010年,2009年,2008年,2007年,2006年
# 0   北京市,23014.59,21330.83,19800.81,17879.4,16251.9...
# 1   天津市,16538.19,15726.93,14442.01,12893.88,11307....
# 2   河北省,29806.11,29421.15,28442.95,26575.01,24515....
# 3   山西省,12766.49,12761.49,12665.25,12112.83,11237....
# 4   内蒙古自治区,17831.51,17770.19,16916.5,15880.58,1435...
# 5   辽宁省,28669.02,28626.58,27213.22,24846.43,22226....
# 6   吉林省,14063.13,13803.14,13046.4,11939.24,10568.8...
# 7   黑龙江省,15083.67,15039.38,14454.91,13691.58,12582...
# 8   上海市,25123.45,23567.7,21818.15,20181.72,19195.6...
# 9   江苏省,70116.38,65088.32,59753.37,54058.22,49110....
# 10  浙江省,42886.49,40173.03,37756.59,34665.33,32318....
# 11  安徽省,22005.63,20848.75,19229.34,17212.05,15300....
# 12  福建省,25979.82,24055.76,21868.49,19701.78,17560....
# 13  江西省,16723.78,15714.63,14410.19,12948.88,11702....
# 14  山东省,63002.33,59426.59,55230.32,50013.24,45361....
# 15  河南省,37002.16,34938.24,32191.3,29599.31,26931.0...
# 16  湖北省,29550.19,27379.22,24791.83,22250.45,19632....
# 17  湖南省,28902.21,27037.32,24621.67,22154.23,19669....
# 18  广东省,72812.55,67809.85,62474.79,57067.92,53210....
# 19  广西壮族自治区,16803.12,15672.89,14449.9,13035.1,1172...
# 20  海南省,3702.76,3500.72,3177.56,2855.54,2522.66,20...
# 21  重庆市,15717.27,14262.6,12783.26,11409.6,10011.37...
# 22  四川省,30053.1,28536.66,26392.07,23872.8,21026.68...
# 23  贵州省,10502.56,9266.39,8086.86,6852.2,5701.84,46...
# 24  云南省,13619.17,12814.59,11832.31,10309.47,8893.1...
# 25  西藏自治区,1026.39,920.83,815.67,701.03,605.83,507....
# 26  陕西省,18021.86,17689.94,16205.45,14453.68,12512....
# 27  甘肃省,6790.32,6836.82,6330.69,5650.2,5020.37,412...
# 28  青海省,2417.05,2303.32,2122.06,1893.54,1670.44,13...
# 29  宁夏回族自治区,2911.77,2752.1,2577.57,2341.29,2102.21...
# 30  新疆维吾尔自治区,9324.8,9273.46,8443.84,7505.31,6610.0...

# %%
df    = pd.read_table("GDP.csv",   # 档名
                       encoding = 'utf8',       # 编码
                       header = 3,              # 指定数据的标题为原始数据之第3行
                       skiprows = [35,36],      # 原始数据之第35, 36行跳过不计
                       sep =','                 # 分隔符设为',' read_table内置分隔符为\t
                     )
df
# Out:
#           地区     2015年     2014年     2013年     2012年     2011年     2010年  \
# 0        北京市  23014.59  21330.83  19800.81  17879.40  16251.93  14113.58
# 1        天津市  16538.19  15726.93  14442.01  12893.88  11307.28   9224.46
# 2        河北省  29806.11  29421.15  28442.95  26575.01  24515.76  20394.26
# 3        山西省  12766.49  12761.49  12665.25  12112.83  11237.55   9200.86
# 4     内蒙古自治区  17831.51  17770.19  16916.50  15880.58  14359.88  11672.00
# 5        辽宁省  28669.02  28626.58  27213.22  24846.43  22226.70  18457.27
# 6        吉林省  14063.13  13803.14  13046.40  11939.24  10568.83   8667.58
# 7       黑龙江省  15083.67  15039.38  14454.91  13691.58  12582.00  10368.60
# 8        上海市  25123.45  23567.70  21818.15  20181.72  19195.69  17165.98
# 9        江苏省  70116.38  65088.32  59753.37  54058.22  49110.27  41425.48
# 10       浙江省  42886.49  40173.03  37756.59  34665.33  32318.85  27722.31
# 11       安徽省  22005.63  20848.75  19229.34  17212.05  15300.65  12359.33
# 12       福建省  25979.82  24055.76  21868.49  19701.78  17560.18  14737.12
# 13       江西省  16723.78  15714.63  14410.19  12948.88  11702.82   9451.26
# 14       山东省  63002.33  59426.59  55230.32  50013.24  45361.85  39169.92
# 15       河南省  37002.16  34938.24  32191.30  29599.31  26931.03  23092.36
# 16       湖北省  29550.19  27379.22  24791.83  22250.45  19632.26  15967.61
# 17       湖南省  28902.21  27037.32  24621.67  22154.23  19669.56  16037.96
# 18       广东省  72812.55  67809.85  62474.79  57067.92  53210.28  46013.06
# 19   广西壮族自治区  16803.12  15672.89  14449.90  13035.10  11720.87   9569.85
# 20       海南省   3702.76   3500.72   3177.56   2855.54   2522.66   2064.50
# 21       重庆市  15717.27  14262.60  12783.26  11409.60  10011.37   7925.58
# 22       四川省  30053.10  28536.66  26392.07  23872.80  21026.68  17185.48
# 23       贵州省  10502.56   9266.39   8086.86   6852.20   5701.84   4602.16
# 24       云南省  13619.17  12814.59  11832.31  10309.47   8893.12   7224.18
# 25     西藏自治区   1026.39    920.83    815.67    701.03    605.83    507.46
# 26       陕西省  18021.86  17689.94  16205.45  14453.68  12512.30  10123.48
# 27       甘肃省   6790.32   6836.82   6330.69   5650.20   5020.37   4120.75
# 28       青海省   2417.05   2303.32   2122.06   1893.54   1670.44   1350.43
# 29   宁夏回族自治区   2911.77   2752.10   2577.57   2341.29   2102.21   1689.65
# 30  新疆维吾尔自治区   9324.80   9273.46   8443.84   7505.31   6610.05   5437.47
#
#        2009年     2008年     2007年     2006年
# 0   12153.03  11115.00   9846.81   8117.78
# 1    7521.85   6719.01   5252.76   4462.74
# 2   17235.48  16011.97  13607.32  11467.60
# 3    7358.31   7315.40   6024.45   4878.61
# 4    9740.25   8496.20   6423.18   4944.25
# 5   15212.49  13668.58  11164.30   9304.52
# 6    7278.75   6426.10   5284.69   4275.12
# 7    8587.00   8314.37   7104.00   6211.80
# 8   15046.45  14069.86  12494.01  10572.24
# 9   34457.30  30981.98  26018.48  21742.05
# 10  22990.35  21462.69  18753.73  15718.47
# 11  10062.82   8851.66   7360.92   6112.50
# 12  12236.53  10823.01   9248.53   7583.85
# 13   7655.18   6971.05   5800.25   4820.53
# 14  33896.65  30933.28  25776.91  21900.19
# 15  19480.46  18018.53  15012.46  12362.79
# 16  12961.10  11328.92   9333.40   7617.47
# 17  13059.69  11555.00   9439.60   7688.67
# 18  39482.56  36796.71  31777.01  26587.76
# 19   7759.16   7021.00   5823.41   4746.16
# 20   1654.21   1503.06   1254.17   1065.67
# 21   6530.01   5793.66   4676.13   3907.23
# 22  14151.28  12601.23  10562.39   8690.24
# 23   3912.68   3561.56   2884.11   2338.98
# 24   6169.75   5692.12   4772.52   3988.14
# 25    441.36    394.85    341.43    290.76
# 26   8169.80   7314.58   5757.29   4743.61
# 27   3387.56   3166.82   2703.98   2277.35
# 28   1081.27   1018.62    797.35    648.50
# 29   1353.31   1203.92    919.11    725.90
# 30   4277.05   4183.21   3523.16   3045.26

# %%
df.head()
# Out:
#        地区     2015年     2014年     2013年     2012年     2011年     2010年  \
# 0     北京市  23014.59  21330.83  19800.81  17879.40  16251.93  14113.58
# 1     天津市  16538.19  15726.93  14442.01  12893.88  11307.28   9224.46
# 2     河北省  29806.11  29421.15  28442.95  26575.01  24515.76  20394.26
# 3     山西省  12766.49  12761.49  12665.25  12112.83  11237.55   9200.86
# 4  内蒙古自治区  17831.51  17770.19  16916.50  15880.58  14359.88  11672.00
#
#       2009年     2008年     2007年     2006年
# 0  12153.03  11115.00   9846.81   8117.78
# 1   7521.85   6719.01   5252.76   4462.74
# 2  17235.48  16011.97  13607.32  11467.60
# 3   7358.31   7315.40   6024.45   4878.61
# 4   9740.25   8496.20   6423.18   4944.25

# %%
df_GDP= pd.read_table("GDP.csv",   
                       encoding = 'utf8',       
                       header = 3,             
                       skiprows = [35,36],      
                       sep =','                
                      )
df_HP= pd.read_table("HP.csv",   # 档名
                       encoding = 'utf8',       
                       header = 3,              
                       skiprows = [35,36],     
                       sep =','                 
                      )

# %%
#2
df = df_GDP

# %%
df.columns
# Out:
# Index(['地区', '2015年', '2014年', '2013年', '2012年', '2011年', '2010年', '2009年',
#        '2008年', '2007年', '2006年'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
df['地区'].head()
# Out:
# 0       北京市
# 1       天津市
# 2       河北省
# 3       山西省
# 4    内蒙古自治区
# Name: 地区, dtype: object

# %%
df['2007年'].head()
# Out:
# 0     9846.81
# 1     5252.76
# 2    13607.32
# 3     6024.45
# 4     6423.18
# Name: 2007年, dtype: float64

# %%
df.dtypes
# Out:
# 地区        object
# 2015年    float64
# 2014年    float64
# 2013年    float64
# 2012年    float64
# 2011年    float64
# 2010年    float64
# 2009年    float64
# 2008年    float64
# 2007年    float64
# 2006年    float64
# dtype: object

# %%
df.columns = [ int(x.replace('年','')) if x!='地区' else x for x in df.columns]
df.columns
# Out:
# Index(['地区', 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006], dtype='object')

# %%
years = [ x for x in df.columns if x!='地区'] 
max(years)
# Out:
# 2015

# %%
df_melted = pd.melt(df, id_vars=['地区'], value_vars=years)

# %%
df_melted.columns
# Out:
# Index(['地区', 'variable', 'value'], dtype='object')

# %%
df_melted.columns = ['地区', '年', 'GDP']
df_melted
# Out:
#            地区     年       GDP
# 0         北京市  2015  23014.59
# 1         天津市  2015  16538.19
# 2         河北省  2015  29806.11
# 3         山西省  2015  12766.49
# 4      内蒙古自治区  2015  17831.51
# 5         辽宁省  2015  28669.02
# 6         吉林省  2015  14063.13
# 7        黑龙江省  2015  15083.67
# 8         上海市  2015  25123.45
# 9         江苏省  2015  70116.38
# 10        浙江省  2015  42886.49
# 11        安徽省  2015  22005.63
# 12        福建省  2015  25979.82
# 13        江西省  2015  16723.78
# 14        山东省  2015  63002.33
# 15        河南省  2015  37002.16
# 16        湖北省  2015  29550.19
# 17        湖南省  2015  28902.21
# 18        广东省  2015  72812.55
# 19    广西壮族自治区  2015  16803.12
# 20        海南省  2015   3702.76
# 21        重庆市  2015  15717.27
# 22        四川省  2015  30053.10
# 23        贵州省  2015  10502.56
# 24        云南省  2015  13619.17
# 25      西藏自治区  2015   1026.39
# 26        陕西省  2015  18021.86
# 27        甘肃省  2015   6790.32
# 28        青海省  2015   2417.05
# 29    宁夏回族自治区  2015   2911.77
# ..        ...   ...       ...
# 280       天津市  2006   4462.74
# 281       河北省  2006  11467.60
# 282       山西省  2006   4878.61
# 283    内蒙古自治区  2006   4944.25
# 284       辽宁省  2006   9304.52
# 285       吉林省  2006   4275.12
# 286      黑龙江省  2006   6211.80
# 287       上海市  2006  10572.24
# 288       江苏省  2006  21742.05
# 289       浙江省  2006  15718.47
# 290       安徽省  2006   6112.50
# 291       福建省  2006   7583.85
# 292       江西省  2006   4820.53
# 293       山东省  2006  21900.19
# 294       河南省  2006  12362.79
# 295       湖北省  2006   7617.47
# 296       湖南省  2006   7688.67
# 297       广东省  2006  26587.76
# 298   广西壮族自治区  2006   4746.16
# 299       海南省  2006   1065.67
# 300       重庆市  2006   3907.23
# 301       四川省  2006   8690.24
# 302       贵州省  2006   2338.98
# 303       云南省  2006   3988.14
# 304     西藏自治区  2006    290.76
# 305       陕西省  2006   4743.61
# 306       甘肃省  2006   2277.35
# 307       青海省  2006    648.50
# 308   宁夏回族自治区  2006    725.90
# 309  新疆维吾尔自治区  2006   3045.26
#
# [310 rows x 3 columns]

# %%
df_GDP_done = df_melted

# %%
df = df_HP
df.columns = [ int(x.replace('年','')) if x!='地区' else x for x in df.columns]
years = [ x for x in df.columns if x!='地区'] 
df_melted = pd.melt(df, id_vars=['地区'], value_vars=years)
df_melted.columns = ['地区', '年', 'HP']
df_HP_done = df_melted
df_HP_done
# Out:
#            地区     年        HP
# 0         北京市  2015  22633.00
# 1         天津市  2015  10107.00
# 2         河北省  2015   5759.00
# 3         山西省  2015   4870.00
# 4      内蒙古自治区  2015   4441.00
# 5         辽宁省  2015   5758.00
# 6         吉林省  2015   5476.00
# 7        黑龙江省  2015   5144.00
# 8         上海市  2015  20949.00
# 9         江苏省  2015   7356.00
# 10        浙江省  2015  10525.00
# 11        安徽省  2015   5457.00
# 12        福建省  2015   8881.00
# 13        江西省  2015   5358.00
# 14        山东省  2015   5560.00
# 15        河南省  2015   4611.00
# 16        湖北省  2015   5863.00
# 17        湖南省  2015   4304.00
# 18        广东省  2015   9796.00
# 19    广西壮族自治区  2015   4960.00
# 20        海南省  2015   9339.00
# 21        重庆市  2015   5486.00
# 22        四川省  2015   5475.00
# 23        贵州省  2015   4415.00
# 24        云南省  2015   5300.00
# 25      西藏自治区  2015   4111.00
# 26        陕西省  2015   5362.00
# 27        甘肃省  2015   4913.00
# 28        青海省  2015   5242.00
# 29    宁夏回族自治区  2015   4413.00
# ..        ...   ...       ...
# 280       天津市  2006   4773.54
# 281       河北省  2006   2111.42
# 282       山西省  2006   1988.18
# 283    内蒙古自治区  2006   1811.37
# 284       辽宁省  2006   3073.44
# 285       吉林省  2006   2009.59
# 286      黑龙江省  2006   2195.55
# 287       上海市  2006   7196.00
# 288       江苏省  2006   3592.19
# 289       浙江省  2006   4774.44
# 290       安徽省  2006   2321.89
# 291       福建省  2006   3993.96
# 292       江西省  2006   1707.99
# 293       山东省  2006   2540.50
# 294       河南省  2006   2011.84
# 295       湖北省  2006   2555.66
# 296       湖南省  2006   1928.44
# 297       广东省  2006   4852.74
# 298   广西壮族自治区  2006   2195.41
# 299       海南省  2006   3787.46
# 300       重庆市  2006   2269.21
# 301       四川省  2006   2270.94
# 302       贵州省  2006   1779.82
# 303       云南省  2006   2380.17
# 304     西藏自治区  2006   1976.46
# 305       陕西省  2006   2461.32
# 306       甘肃省  2006   1779.76
# 307       青海省  2006   1920.56
# 308   宁夏回族自治区  2006   2063.07
# 309  新疆维吾尔自治区  2006   1858.09
#
# [310 rows x 3 columns]

# %%
#3
df_p = df_HP_done.join(df_GDP_done,lsuffix='', rsuffix='_GDP')
df_p
# Out:
#            地区     年        HP    地区_GDP 年_GDP       GDP
# 0         北京市  2015  22633.00       北京市  2015  23014.59
# 1         天津市  2015  10107.00       天津市  2015  16538.19
# 2         河北省  2015   5759.00       河北省  2015  29806.11
# 3         山西省  2015   4870.00       山西省  2015  12766.49
# 4      内蒙古自治区  2015   4441.00    内蒙古自治区  2015  17831.51
# 5         辽宁省  2015   5758.00       辽宁省  2015  28669.02
# 6         吉林省  2015   5476.00       吉林省  2015  14063.13
# 7        黑龙江省  2015   5144.00      黑龙江省  2015  15083.67
# 8         上海市  2015  20949.00       上海市  2015  25123.45
# 9         江苏省  2015   7356.00       江苏省  2015  70116.38
# 10        浙江省  2015  10525.00       浙江省  2015  42886.49
# 11        安徽省  2015   5457.00       安徽省  2015  22005.63
# 12        福建省  2015   8881.00       福建省  2015  25979.82
# 13        江西省  2015   5358.00       江西省  2015  16723.78
# 14        山东省  2015   5560.00       山东省  2015  63002.33
# 15        河南省  2015   4611.00       河南省  2015  37002.16
# 16        湖北省  2015   5863.00       湖北省  2015  29550.19
# 17        湖南省  2015   4304.00       湖南省  2015  28902.21
# 18        广东省  2015   9796.00       广东省  2015  72812.55
# 19    广西壮族自治区  2015   4960.00   广西壮族自治区  2015  16803.12
# 20        海南省  2015   9339.00       海南省  2015   3702.76
# 21        重庆市  2015   5486.00       重庆市  2015  15717.27
# 22        四川省  2015   5475.00       四川省  2015  30053.10
# 23        贵州省  2015   4415.00       贵州省  2015  10502.56
# 24        云南省  2015   5300.00       云南省  2015  13619.17
# 25      西藏自治区  2015   4111.00     西藏自治区  2015   1026.39
# 26        陕西省  2015   5362.00       陕西省  2015  18021.86
# 27        甘肃省  2015   4913.00       甘肃省  2015   6790.32
# 28        青海省  2015   5242.00       青海省  2015   2417.05
# 29    宁夏回族自治区  2015   4413.00   宁夏回族自治区  2015   2911.77
# ..        ...   ...       ...       ...   ...       ...
# 280       天津市  2006   4773.54       天津市  2006   4462.74
# 281       河北省  2006   2111.42       河北省  2006  11467.60
# 282       山西省  2006   1988.18       山西省  2006   4878.61
# 283    内蒙古自治区  2006   1811.37    内蒙古自治区  2006   4944.25
# 284       辽宁省  2006   3073.44       辽宁省  2006   9304.52
# 285       吉林省  2006   2009.59       吉林省  2006   4275.12
# 286      黑龙江省  2006   2195.55      黑龙江省  2006   6211.80
# 287       上海市  2006   7196.00       上海市  2006  10572.24
# 288       江苏省  2006   3592.19       江苏省  2006  21742.05
# 289       浙江省  2006   4774.44       浙江省  2006  15718.47
# 290       安徽省  2006   2321.89       安徽省  2006   6112.50
# 291       福建省  2006   3993.96       福建省  2006   7583.85
# 292       江西省  2006   1707.99       江西省  2006   4820.53
# 293       山东省  2006   2540.50       山东省  2006  21900.19
# 294       河南省  2006   2011.84       河南省  2006  12362.79
# 295       湖北省  2006   2555.66       湖北省  2006   7617.47
# 296       湖南省  2006   1928.44       湖南省  2006   7688.67
# 297       广东省  2006   4852.74       广东省  2006  26587.76
# 298   广西壮族自治区  2006   2195.41   广西壮族自治区  2006   4746.16
# 299       海南省  2006   3787.46       海南省  2006   1065.67
# 300       重庆市  2006   2269.21       重庆市  2006   3907.23
# 301       四川省  2006   2270.94       四川省  2006   8690.24
# 302       贵州省  2006   1779.82       贵州省  2006   2338.98
# 303       云南省  2006   2380.17       云南省  2006   3988.14
# 304     西藏自治区  2006   1976.46     西藏自治区  2006    290.76
# 305       陕西省  2006   2461.32       陕西省  2006   4743.61
# 306       甘肃省  2006   1779.76       甘肃省  2006   2277.35
# 307       青海省  2006   1920.56       青海省  2006    648.50
# 308   宁夏回族自治区  2006   2063.07   宁夏回族自治区  2006    725.90
# 309  新疆维吾尔自治区  2006   1858.09  新疆维吾尔自治区  2006   3045.26
#
# [310 rows x 6 columns]

# %%
df_p.drop(["地区_GDP","年_GDP"], axis=1)
# Out:
#            地区     年        HP       GDP
# 0         北京市  2015  22633.00  23014.59
# 1         天津市  2015  10107.00  16538.19
# 2         河北省  2015   5759.00  29806.11
# 3         山西省  2015   4870.00  12766.49
# 4      内蒙古自治区  2015   4441.00  17831.51
# 5         辽宁省  2015   5758.00  28669.02
# 6         吉林省  2015   5476.00  14063.13
# 7        黑龙江省  2015   5144.00  15083.67
# 8         上海市  2015  20949.00  25123.45
# 9         江苏省  2015   7356.00  70116.38
# 10        浙江省  2015  10525.00  42886.49
# 11        安徽省  2015   5457.00  22005.63
# 12        福建省  2015   8881.00  25979.82
# 13        江西省  2015   5358.00  16723.78
# 14        山东省  2015   5560.00  63002.33
# 15        河南省  2015   4611.00  37002.16
# 16        湖北省  2015   5863.00  29550.19
# 17        湖南省  2015   4304.00  28902.21
# 18        广东省  2015   9796.00  72812.55
# 19    广西壮族自治区  2015   4960.00  16803.12
# 20        海南省  2015   9339.00   3702.76
# 21        重庆市  2015   5486.00  15717.27
# 22        四川省  2015   5475.00  30053.10
# 23        贵州省  2015   4415.00  10502.56
# 24        云南省  2015   5300.00  13619.17
# 25      西藏自治区  2015   4111.00   1026.39
# 26        陕西省  2015   5362.00  18021.86
# 27        甘肃省  2015   4913.00   6790.32
# 28        青海省  2015   5242.00   2417.05
# 29    宁夏回族自治区  2015   4413.00   2911.77
# ..        ...   ...       ...       ...
# 280       天津市  2006   4773.54   4462.74
# 281       河北省  2006   2111.42  11467.60
# 282       山西省  2006   1988.18   4878.61
# 283    内蒙古自治区  2006   1811.37   4944.25
# 284       辽宁省  2006   3073.44   9304.52
# 285       吉林省  2006   2009.59   4275.12
# 286      黑龙江省  2006   2195.55   6211.80
# 287       上海市  2006   7196.00  10572.24
# 288       江苏省  2006   3592.19  21742.05
# 289       浙江省  2006   4774.44  15718.47
# 290       安徽省  2006   2321.89   6112.50
# 291       福建省  2006   3993.96   7583.85
# 292       江西省  2006   1707.99   4820.53
# 293       山东省  2006   2540.50  21900.19
# 294       河南省  2006   2011.84  12362.79
# 295       湖北省  2006   2555.66   7617.47
# 296       湖南省  2006   1928.44   7688.67
# 297       广东省  2006   4852.74  26587.76
# 298   广西壮族自治区  2006   2195.41   4746.16
# 299       海南省  2006   3787.46   1065.67
# 300       重庆市  2006   2269.21   3907.23
# 301       四川省  2006   2270.94   8690.24
# 302       贵州省  2006   1779.82   2338.98
# 303       云南省  2006   2380.17   3988.14
# 304     西藏自治区  2006   1976.46    290.76
# 305       陕西省  2006   2461.32   4743.61
# 306       甘肃省  2006   1779.76   2277.35
# 307       青海省  2006   1920.56    648.50
# 308   宁夏回族自治区  2006   2063.07    725.90
# 309  新疆维吾尔自治区  2006   1858.09   3045.26
#
# [310 rows x 4 columns]

# %%
df_p.drop(["地区_GDP","年_GDP"], axis=1).set_index(["地区","年"])
# Out:
#                      HP       GDP
# 地区       年
# 北京市      2015  22633.00  23014.59
# 天津市      2015  10107.00  16538.19
# 河北省      2015   5759.00  29806.11
# 山西省      2015   4870.00  12766.49
# 内蒙古自治区   2015   4441.00  17831.51
# 辽宁省      2015   5758.00  28669.02
# 吉林省      2015   5476.00  14063.13
# 黑龙江省     2015   5144.00  15083.67
# 上海市      2015  20949.00  25123.45
# 江苏省      2015   7356.00  70116.38
# 浙江省      2015  10525.00  42886.49
# 安徽省      2015   5457.00  22005.63
# 福建省      2015   8881.00  25979.82
# 江西省      2015   5358.00  16723.78
# 山东省      2015   5560.00  63002.33
# 河南省      2015   4611.00  37002.16
# 湖北省      2015   5863.00  29550.19
# 湖南省      2015   4304.00  28902.21
# 广东省      2015   9796.00  72812.55
# 广西壮族自治区  2015   4960.00  16803.12
# 海南省      2015   9339.00   3702.76
# 重庆市      2015   5486.00  15717.27
# 四川省      2015   5475.00  30053.10
# 贵州省      2015   4415.00  10502.56
# 云南省      2015   5300.00  13619.17
# 西藏自治区    2015   4111.00   1026.39
# 陕西省      2015   5362.00  18021.86
# 甘肃省      2015   4913.00   6790.32
# 青海省      2015   5242.00   2417.05
# 宁夏回族自治区  2015   4413.00   2911.77
# ...                 ...       ...
# 天津市      2006   4773.54   4462.74
# 河北省      2006   2111.42  11467.60
# 山西省      2006   1988.18   4878.61
# 内蒙古自治区   2006   1811.37   4944.25
# 辽宁省      2006   3073.44   9304.52
# 吉林省      2006   2009.59   4275.12
# 黑龙江省     2006   2195.55   6211.80
# 上海市      2006   7196.00  10572.24
# 江苏省      2006   3592.19  21742.05
# 浙江省      2006   4774.44  15718.47
# 安徽省      2006   2321.89   6112.50
# 福建省      2006   3993.96   7583.85
# 江西省      2006   1707.99   4820.53
# 山东省      2006   2540.50  21900.19
# 河南省      2006   2011.84  12362.79
# 湖北省      2006   2555.66   7617.47
# 湖南省      2006   1928.44   7688.67
# 广东省      2006   4852.74  26587.76
# 广西壮族自治区  2006   2195.41   4746.16
# 海南省      2006   3787.46   1065.67
# 重庆市      2006   2269.21   3907.23
# 四川省      2006   2270.94   8690.24
# 贵州省      2006   1779.82   2338.98
# 云南省      2006   2380.17   3988.14
# 西藏自治区    2006   1976.46    290.76
# 陕西省      2006   2461.32   4743.61
# 甘肃省      2006   1779.76   2277.35
# 青海省      2006   1920.56    648.50
# 宁夏回族自治区  2006   2063.07    725.90
# 新疆维吾尔自治区 2006   1858.09   3045.26
#
# [310 rows x 2 columns]

# %%
df_pp = df_p.drop(["地区_GDP","年_GDP"], axis=1).set_index(["地区","年"])

# %%
df_pp.query("年==2015")
# Out:
#                     HP       GDP
# 地区       年
# 北京市      2015  22633.0  23014.59
# 天津市      2015  10107.0  16538.19
# 河北省      2015   5759.0  29806.11
# 山西省      2015   4870.0  12766.49
# 内蒙古自治区   2015   4441.0  17831.51
# 辽宁省      2015   5758.0  28669.02
# 吉林省      2015   5476.0  14063.13
# 黑龙江省     2015   5144.0  15083.67
# 上海市      2015  20949.0  25123.45
# 江苏省      2015   7356.0  70116.38
# 浙江省      2015  10525.0  42886.49
# 安徽省      2015   5457.0  22005.63
# 福建省      2015   8881.0  25979.82
# 江西省      2015   5358.0  16723.78
# 山东省      2015   5560.0  63002.33
# 河南省      2015   4611.0  37002.16
# 湖北省      2015   5863.0  29550.19
# 湖南省      2015   4304.0  28902.21
# 广东省      2015   9796.0  72812.55
# 广西壮族自治区  2015   4960.0  16803.12
# 海南省      2015   9339.0   3702.76
# 重庆市      2015   5486.0  15717.27
# 四川省      2015   5475.0  30053.10
# 贵州省      2015   4415.0  10502.56
# 云南省      2015   5300.0  13619.17
# 西藏自治区    2015   4111.0   1026.39
# 陕西省      2015   5362.0  18021.86
# 甘肃省      2015   4913.0   6790.32
# 青海省      2015   5242.0   2417.05
# 宁夏回族自治区  2015   4413.0   2911.77
# 新疆维吾尔自治区 2015   4653.0   9324.80

# %%
#4
# %matplotlib inline
df_pp.query("年==2015").plot(kind='scatter', x='HP', y='GDP', 
          title = 'HP与GDP的关系：分省数据')

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pylab
mpl.rcParams['font.sans-serif']=['SimHei']
mpl.rcParams['axes.unicode_minus']=False

df_plot = df_pp.query("年==2015")
df_plot.plot(kind='scatter', x='HP', y='GDP', 
          title = 'HP与GDP的关系：分省数据')

# %%
#5
import numpy as np
fit = np.polyfit(x=df_pp.query("年==2015")['HP'], y=df_pp.query("年==2015")['GDP'], deg=1)

# %%
x=df_plot['HP']
y=df_plot['GDP']
ax = df_plot.plot(kind='scatter', x='HP', y='GDP', 
          title = 'HP与GDP的关系：分省数据')
ax.plot(x, fit[0] * x + fit[1], color='red')
ax.scatter(x, y)

# %%
#6
df_pp
# Out:
#                      HP       GDP
# 地区       年
# 北京市      2015  22633.00  23014.59
# 天津市      2015  10107.00  16538.19
# 河北省      2015   5759.00  29806.11
# 山西省      2015   4870.00  12766.49
# 内蒙古自治区   2015   4441.00  17831.51
# 辽宁省      2015   5758.00  28669.02
# 吉林省      2015   5476.00  14063.13
# 黑龙江省     2015   5144.00  15083.67
# 上海市      2015  20949.00  25123.45
# 江苏省      2015   7356.00  70116.38
# 浙江省      2015  10525.00  42886.49
# 安徽省      2015   5457.00  22005.63
# 福建省      2015   8881.00  25979.82
# 江西省      2015   5358.00  16723.78
# 山东省      2015   5560.00  63002.33
# 河南省      2015   4611.00  37002.16
# 湖北省      2015   5863.00  29550.19
# 湖南省      2015   4304.00  28902.21
# 广东省      2015   9796.00  72812.55
# 广西壮族自治区  2015   4960.00  16803.12
# 海南省      2015   9339.00   3702.76
# 重庆市      2015   5486.00  15717.27
# 四川省      2015   5475.00  30053.10
# 贵州省      2015   4415.00  10502.56
# 云南省      2015   5300.00  13619.17
# 西藏自治区    2015   4111.00   1026.39
# 陕西省      2015   5362.00  18021.86
# 甘肃省      2015   4913.00   6790.32
# 青海省      2015   5242.00   2417.05
# 宁夏回族自治区  2015   4413.00   2911.77
# ...                 ...       ...
# 天津市      2006   4773.54   4462.74
# 河北省      2006   2111.42  11467.60
# 山西省      2006   1988.18   4878.61
# 内蒙古自治区   2006   1811.37   4944.25
# 辽宁省      2006   3073.44   9304.52
# 吉林省      2006   2009.59   4275.12
# 黑龙江省     2006   2195.55   6211.80
# 上海市      2006   7196.00  10572.24
# 江苏省      2006   3592.19  21742.05
# 浙江省      2006   4774.44  15718.47
# 安徽省      2006   2321.89   6112.50
# 福建省      2006   3993.96   7583.85
# 江西省      2006   1707.99   4820.53
# 山东省      2006   2540.50  21900.19
# 河南省      2006   2011.84  12362.79
# 湖北省      2006   2555.66   7617.47
# 湖南省      2006   1928.44   7688.67
# 广东省      2006   4852.74  26587.76
# 广西壮族自治区  2006   2195.41   4746.16
# 海南省      2006   3787.46   1065.67
# 重庆市      2006   2269.21   3907.23
# 四川省      2006   2270.94   8690.24
# 贵州省      2006   1779.82   2338.98
# 云南省      2006   2380.17   3988.14
# 西藏自治区    2006   1976.46    290.76
# 陕西省      2006   2461.32   4743.61
# 甘肃省      2006   1779.76   2277.35
# 青海省      2006   1920.56    648.50
# 宁夏回族自治区  2006   2063.07    725.90
# 新疆维吾尔自治区 2006   1858.09   3045.26
#
# [310 rows x 2 columns]

# %%
df_pp['desc'] = df_pp.index.get_level_values(0)

# %%
from bokeh.plotting import figure, output_file, show, output_notebook
from bokeh.models import HoverTool, BoxSelectTool

title = '分省数据' 
xlabel = 'HP：房价' 
ylabel = 'GDP：产值'

hover = HoverTool(
    tooltips=[
        ( '房价',  '$x{0,F}'), 
        ( '产值',  '$y{0,F}'),
        ( '地区',  '@desc'  ),
    ]
)

TOOLS = [hover, "pan, wheel_zoom, box_zoom, reset, resize"]
fig = figure(plot_width=800, plot_height=600,
           x_axis_label = xlabel, y_axis_label = ylabel, 
           title=title, tools=TOOLS)

df_plot = df_pp.query("年==2015")

fig.circle("HP", "GDP",
         source = df_plot,
         fill_alpha=0.6, line_color=None, size= 30)

#regression line
xs = [min(df_plot["HP"]), max(df_plot["HP"])]
fig.line(x=xs, y=[ fit[0] * x + fit[1] for x in xs] )

output_notebook() # 输出到IPython/Jupyter Notebook，若要输出到他处需调整
#output_file('by_provinces.htm') # 输出到 htm
show(fig)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="cfc379ac-a298-460b-914e-1698596db352">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="da158f4c-1236-48de-996e-656811302e27"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("da158f4c-1236-48de-996e-656811302e27");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("da158f4c-1236-48de-996e-656811302e27");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'da158f4c-1236-48de-996e-656811302e27' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"21365c6c-5804-47f0-b2ec-85263802d533":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"99f9b023-9bd7-4e43-8b40-d8d95005eca3","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"a59471c6-f695-4795-856b-68e6492c790b","type":"ColumnDataSource"},"glyph":{"id":"ddec0a6f-29f2-461c-a873-8c607acb7b68","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"70128fb7-7590-49cd-927e-e8342661e459","type":"Line"},"selection_glyph":null},"id":"a622a27f-199a-400e-a189-cfe047995eda","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"41c12c76-3a19-484e-80e3-ef1f31104237","subtype":"Figure","type":"Plot"}},"id":"95709688-5a26-4fea-96f6-cf2db0033c62","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"99f9b023-9bd7-4e43-8b40-d8d95005eca3","type":"BoxAnnotation"},"plot":{"id":"41c12c76-3a19-484e-80e3-ef1f31104237","subtype":"Figure","type":"Plot"}},"id":"196f9ca5-bff0-4b16-802e-b4bfd2ffff45","type":"BoxZoomTool"},{"attributes":{"callback":null,"plot":{"id":"41c12c76-3a19-484e-80e3-ef1f31104237","subtype":"Figure","type":"Plot"},"tooltips":[["\u623f\u4ef7","$x{0,F}"],["\u4ea7\u503c","$y{0,F}"],["\u5730\u533a","@desc"]]},"id":"2c7a1dc3-e68d-4d0a-accb-7b31f333b527","type":"HoverTool"},{"attributes":{"plot":{"id":"41c12c76-3a19-484e-80e3-ef1f31104237","subtype":"Figure","type":"Plot"}},"id":"9fa150c1-3111-4708-8621-e88678eb0125","type":"ResetTool"},{"attributes":{"plot":null,"text":"\u5206\u7701\u6570\u636e"},"id":"50147392-d8a7-4117-bf7b-155b2233f844","type":"Title"},{"attributes":{"plot":{"id":"41c12c76-3a19-484e-80e3-ef1f31104237","subtype":"Figure","type":"Plot"}},"id":"4a0c71bb-c2c2-45cb-bbe8-8ffd3bc48b03","type":"ResizeTool"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ddec0a6f-29f2-461c-a873-8c607acb7b68","type":"Line"},{"attributes":{},"id":"739cb082-f559-4679-8568-8603818e8fe3","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"value":"#1f77b4"},"line_color":{"value":null},"size":{"units":"screen","value":30},"x":{"field":"HP"},"y":{"field":"GDP"}},"id":"d9657c97-4c00-4f6a-9b60-effd7a793635","type":"Circle"},{"attributes":{},"id":"96f744c0-f6ee-401a-9b09-aa7aea6a0136","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2c7a1dc3-e68d-4d0a-accb-7b31f333b527","type":"HoverTool"},{"id":"2621bfaf-b48f-45a0-9360-ebb230f023f4","type":"PanTool"},{"id":"95709688-5a26-4fea-96f6-cf2db0033c62","type":"WheelZoomTool"},{"id":"196f9ca5-bff0-4b16-802e-b4bfd2ffff45","type":"BoxZoomTool"},{"id":"9fa150c1-3111-4708-8621-e88678eb0125","type":"ResetTool"},{"id":"4a0c71bb-c2c2-45cb-bbe8-8ffd3bc48b03","type":"ResizeTool"}]},"id":"bc850dd2-1fb8-48fa-910e-e9d149fcbe8c","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[4111.0,22633.0],"y":[21147.81754883226,35118.02627302727]}},"id":"a59471c6-f695-4795-856b-68e6492c790b","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":30},"x":{"field":"HP"},"y":{"field":"GDP"}},"id":"e86dd63d-79d1-4bfa-89ac-aaa67c42d347","type":"Circle"},{"attributes":{},"id":"9d213564-c48a-46a4-bd52-16c375fc6d55","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["HP","GDP","desc","\u5730\u533a_\u5e74"],"data":{"GDP":{"__ndarray__":"KVyPwqV51kCPwvUojCbQQKRwPQqHG91AhetRuD7vyEA9Ctej4GnRQHsUrkdB/9tAPQrXo5B3y0ApXI/C1XXNQM3MzMzciNhASOF6FEYe8UDhehSuz/DkQB+F61FofdVArkfhevRe2UC4HoXr8VTQQPYoXI9Kw+5A7FG4HkUR4kCPwvUojNvcQArXo3CNOdxAzczMzMjG8UDhehSux2 ...

# %%
#7
from bokeh.plotting import figure
from bokeh.io import output_notebook, push_notebook, show
from bokeh.models import CustomJS, Slider,HoverTool, BoxSelectTool
from bokeh.layouts import column

title = '分省数据' 
xlabel = 'HP：房价高低' 
ylabel = 'GDP：产值大小'
hover = HoverTool(
    tooltips=[
        ( '房价高低',  '$x{0,F}'), 
        ( '产值大小',  '$y{0,F}'),
        ( '地区',  '@desc'  ),
    ]
)

TOOLS = [hover, "pan, wheel_zoom, box_zoom, reset, resize"]

fig = figure(plot_width=800, plot_height=600,
           x_axis_label = xlabel, y_axis_label = ylabel, 
           title=title, tools=TOOLS)

yr_min = df_pp.index.get_level_values(1).min()
df_plot = df_pp.query("年=={yr}".format(yr=yr_min))
plt = fig.circle("HP", "GDP",
         source = df_plot,
         fill_alpha=0.6, line_color=None, size= 15)


def update_plot(year):
    #plt.data_source.data = df_pp.query("年=={yr}".format(yr=year))
    plt.data_source.data['HP'] = list(df_pp.query("年=={yr}".format(yr=year)).loc[:,['HP']].iloc[:,0].values)
    plt.data_source.data['GDP'] = list(df_pp.query("年=={yr}".format(yr=year)).loc[:,['GDP']].iloc[:,0].values)
    plt.data_source.data['地区_年'] = [(x[0],int(year)) for x in plt.data_source.data['地区_年']]

    push_notebook(handle=bokeh_handle)  
    print (year)
    ##### new notebook cell #####

callback = CustomJS(code="""
if (IPython.notebook.kernel !== undefined) {
    var kernel = IPython.notebook.kernel;
    cmd = "update_plot(" + cb_obj.value + ")";
    kernel.execute(cmd, {}, {});
}
""")

slider = Slider(start=df_pp.index.get_level_values(1).min(), 
                end=df_pp.index.get_level_values(1).max(),
                value=1,
                step=1,
                title="年",
                callback=callback)
output_notebook()

bokeh_handle = show(column(slider, fig), notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e90f59fc-e997-457c-8ec4-5030c0475413">Loading BokehJS ...</span>
#     </div>
# C:\ProgramData\Anaconda3\lib\site-packages\bokeh\core\json_encoder.py:73: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access Timestamp as pandas.Timestamp
#   if pd and isinstance(obj, pd.tslib.Timestamp):
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ccc62445-f6cc-440d-acb6-d424e1c33f96"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ccc62445-f6cc-440d-acb6-d424e1c33f96");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("5a60f82b-06b4-4df1-9036-53614267d96f", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ccc62445-f6cc-440d-acb6-d424e1c33f96");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ccc62445-f6cc-440d-acb6-d424e1c33f96' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"93f2537a-26b3-4b4d-a9f4-3ecd91346395":{"roots":{"references":[{"attributes":{"data_source":{"id":"7417aed0-99c6-4e45-bb84-a06cf09d242e","type":"ColumnDataSource"},"glyph":{"id":"dd5b2315-ae16-46fc-ae67-e16243a0fe46","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"9fc4c303-b249-458e-8f5b-7c3fc4edd192","type":"Circle"},"selection_glyph":null},"id":"76a33c19-1019-43a6-b410-403d8a86a677","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":15},"x":{"field":"HP"},"y":{"field":"GDP"}},"id":"9fc4c303-b249-458e-8f5b-7c3fc4edd192","type":"Circle"},{"attributes":{},"id":"0238e98d-4fc0-4c88-98c1-3cb9038bc470","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"ee7d1e6a-da2f-4928-949f-cf591d00ef9d","subtype":"Figure","type":"Plot"}},"id":"d46ea0fb-de1b-4e0f-9db9-801c45ad7a1c","type":"PanTool"},{"attributes":{"code":"\nif (IPython.notebook.kernel !== undefined) {\n    var kernel = IPython.notebook.kernel;\n    cmd = \"update_plot(\" + cb_obj.value + \")\";\n    kernel.execute(cmd, {}, {});\n}\n"},"id":"872ef460-b6fe-44db-a771-70734388867b","type":"CustomJS"},{"attributes":{"callback":{"id":"872ef460-b6fe-44db-a771-70734388867b","type":"CustomJS"},"end":2015,"start":2006,"step":1,"title":"\u5e74","value":1},"id":"487bd1e0-9d27-4daf-84a7-24fe8a8f98a6","type":"Slider"},{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"value":"#1f77b4"},"line_color":{"value":null},"size":{"units":"screen","value":15},"x":{"field":"HP"},"y":{"field":"GDP"}},"id":"dd5b2315-ae16-46fc-ae67-e16243a0fe46","type":"Circle"},{"attributes":{},"id":"f5f5fa2b-74a7-4923-850c-723d1ac895d6","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"ee7d1e6a-da2f-4928-949f-cf591d00ef9d","subtype":"Figure","type":"Plot"},"ticker":{"id":"29454a59-9b33-4381-a5d1-88090696fbb8","type":"BasicTicker"}},"id":"8257a24b-2004-4444-a7f1-1c62c259eb77","type":"Grid"},{"attributes":{"callback":null,"column_names":["HP","GDP","desc","\u5730\u533a_\u5e74"],"data":{"GDP":{"__ndarray__":"","dtype":"float64","shape":[31]},"HP":{"__ndarray__":"","dtype":"float64","shape":[31]},"desc":["\u5317\u4eac\u5e02","\u5929\u6d25\u5e02","\u6cb3\u5317\u7701","\u5c71\u897f\u7701","\u5185\u8499\u53e4\u81ea\u6cbb\u533a","\u8fbd\u5b81\u7701","\u5409\u6797\u7701","\u9ed1\u9f99\u6c5f\u7701","\u4e0a\u6d77\u5e02","\u6c5f\u82cf\u7701","\u6d59\u6c5f\u7701","\u5b89\u5fbd\u7701","\u798f\u5efa\u7701","\u6c5f\u897f\u7701","\u5c71\u4e1c\u7701","\u6cb3\u5357\u7701","\u6e56\u5317\u7701","\u6e56\u5357\u7701","\u5e7f\u4e1c\u7701","\u5e7f\u897f\u58ee\u65cf\u81ea\u6cbb\u533a","\u6d77\u5357\u7701","\u91cd\u5e86\u5e02","\u56db\u5ddd\u7701","\u8d35\u5dde\u7701","\u4e91\u5357\u7701","\u897f\u85cf\u81ea\u6cbb\u533a","\u9655\u897f\u7701","\u7518\u8083\u7701","\u9752\u6d77\u7701","\u5b81\u590f\u56de\u65cf\u81ea\u6cbb\u533a","\u65b0\u7586\u7ef4\u543e\u5c14\u81ea\u6cbb\u533a"],"\u5730\u533a_\u5e74":[["\u5317\u4eac\u5e02",2006],["\u5929\u6d25\u5e02",2006],["\u6cb3\u5317\u7701",2006],["\u5c71\u897f\u7701",2006],["\u5185\u8499\u53e4\u81ea\u6cbb\u533a",2006],["\u8fbd\u5b81\u7701",2006],["\u5409\u6797\u7701",2006],["\u9ed1\u9f99\u6c5f\u7701",2006],["\u4e0a\u6d77\u5e ...

# %%
#8
yr = 2015
df_plot = df_pp.query("年=={yr}".format(yr=yr_min))
# Regression Using Pandas and Statsmodels
fit = np.polyfit(x=df_plot['HP'], 
                 y=df_plot['GDP'], deg=1)

# %%
df_plot['expected'] =  [ fit[0] * x + fit[1] for x in df_plot['HP']] 
df_plot['difference'] =  df_plot['GDP'] - df_plot['expected']
df_plot['difference_ratio'] = ( df_plot['GDP'] - df_plot['expected'] ) /df_plot['HP']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_plot.sort_values(by='difference_ratio')
# Out:
#                     HP       GDP      desc      expected    difference  \
# 地区       年
# 西藏自治区    2006  1976.46    290.76     西藏自治区   6152.759033  -5861.999033
# 青海省      2006  1920.56    648.50       青海省   6072.134276  -5423.634276
# 宁夏回族自治区  2006  2063.07    725.90   宁夏回族自治区   6277.676927  -5551.776927
# 海南省      2006  3787.46   1065.67       海南省   8764.770411  -7699.100411
# 甘肃省      2006  1779.76   2277.35       甘肃省   5869.057963  -3591.707963
# 贵州省      2006  1779.82   2338.98       贵州省   5869.144501  -3530.164501
# 新疆维吾尔自治区 2006  1858.09   3045.26  新疆维吾尔自治区   5982.033585  -2936.773585
# 天津市      2006  4773.54   4462.74       天津市  10186.996905  -5724.256905
# 重庆市      2006  2269.21   3907.23       重庆市   6574.993341  -2667.763341
# 云南省      2006  2380.17   3988.14       云南省   6735.031321  -2746.891321
# 吉林省      2006  2009.59   4275.12       吉林省   6200.542543  -1925.422543
# 北京市      2006  8279.51   8117.78       北京市  15243.669203  -7125.889203
# 陕西省      2006  2461.32   4743.61       陕西省   6852.074239  -2108.464239
# 广西壮族自治区  2006  2195.41   4746.16   广西壮族自治区   6468.551353  -1722.391353
# 山西省      2006  1988.18   4878.61       山西省   6169.662829  -1291.052829
# 江西省      2006  1707.99   4820.53       江西省   5765.543851   -945.013851
# 内蒙古自治区   2006  1811.37   4944.25    内蒙古自治区   5914.649172   -970.399172
# 上海市      2006  7196.00  10572.24       上海市  13680.919093  -3108.679093
# 福建省      2006  3993.96   7583.85       福建省   9062.606055  -1478.756055
# 安徽省      2006  2321.89   6112.50       安徽省   6650.973882   -538.473882
# 黑龙江省     2006  2195.55   6211.80      黑龙江省   6468.753276   -256.953276
# 湖北省      2006  2555.66   7617.47       湖北省   6988.141137    629.328863
# 辽宁省      2006  3073.44   9304.52       辽宁省   7734.936969   1569.583031
# 湖南省      2006  1928.44   7688.67       湖南省   6083.499626   1605.170374
# 四川省      2006  2270.94   8690.24       四川省   6577.488526   2112.751474
# 浙江省      2006  4774.44  15718.47       浙江省  10188.294978   5530.175022
# 河北省      2006  2111.42  11467.60       河北省   6347.412294   5120.187706
# 河南省      2006  2011.84  12362.79       河南省   6203.787726   6159.002274
# 广东省      2006  4852.74  26587.76       广东省  10301.227331  16286.532669
# 江苏省      2006  3592.19  21742.05       江苏省   8483.131835  13258.918165
# 山东省      2006  2540.50  21900.19       山东省   6966.275818  14933.914182
#
#                difference_ratio
# 地区       年
# 西藏自治区    2006         -2.965908
# 青海省      2006         -2.823986
# 宁夏回族自治区  2006         -2.691027
# 海南省      2006         -2.032787
# 甘肃省      2006         -2.018086
# 贵州省      2006         -1.983439
# 新疆维吾尔自治区 2006         -1.580534
# 天津市      2006         -1.199164
# 重庆市      2006         -1.175635
# 云南省      2006         -1.154074
# 吉林省      2006         -0.958117
# 北京市      2006         -0.860666
# 陕西省      2006         -0.856640
# 广西壮族自治区  2006         -0.784542
# 山西省      2006         -0.649364
# 江西省      2006         -0.553290
# 内蒙古自治区   2006         -0.535727
# 上海市      2006         -0.432001
# 福建省      2006         -0.370248
# 安徽省      2006         -0.231912
# 黑龙江省     2006         -0.117034
# 湖北省      2006          0.246249
# 辽宁省      2006          0.510693
# 湖南省      2006          0.832367
# 四川省      2006          0.930342
# 浙江省      2006          1.158288
# 河北省      2006          2.424997
# 河南省      2006          3.061378
# 广东省      2006          3.356152
# 江苏省      2006          3.691040
# 山东省      2006          5.878337

# %%
df_plot.sort_values(by='difference_ratio')[['difference_ratio']]
# Out:
#                difference_ratio
# 地区       年
# 西藏自治区    2006         -2.965908
# 青海省      2006         -2.823986
# 宁夏回族自治区  2006         -2.691027
# 海南省      2006         -2.032787
# 甘肃省      2006         -2.018086
# 贵州省      2006         -1.983439
# 新疆维吾尔自治区 2006         -1.580534
# 天津市      2006         -1.199164
# 重庆市      2006         -1.175635
# 云南省      2006         -1.154074
# 吉林省      2006         -0.958117
# 北京市      2006         -0.860666
# 陕西省      2006         -0.856640
# 广西壮族自治区  2006         -0.784542
# 山西省      2006         -0.649364
# 江西省      2006         -0.553290
# 内蒙古自治区   2006         -0.535727
# 上海市      2006         -0.432001
# 福建省      2006         -0.370248
# 安徽省      2006         -0.231912
# 黑龙江省     2006         -0.117034
# 湖北省      2006          0.246249
# 辽宁省      2006          0.510693
# 湖南省      2006          0.832367
# 四川省      2006          0.930342
# 浙江省      2006          1.158288
# 河北省      2006          2.424997
# 河南省      2006          3.061378
# 广东省      2006          3.356152
# 江苏省      2006          3.691040
# 山东省      2006          5.878337

# %%
df_output = df_plot.sort_values(by='difference_ratio')[['difference_ratio']]
df_output.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th></th>\n      <th>difference_ratio</th>\n    </tr>\n    <tr>\n      <th>地区</th>\n      <th>年</th>\n      <th></th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>西藏自治区</th>\n      <th>2006</th>\n      <td>-2.965908</td>\n    </tr>\n    <tr>\n      <th>青海省</th>\n      <th>2006</th>\n      <td>-2.823986</td>\n    </tr>\n    <tr>\n      <th>宁夏回族自治区</th>\n      <th>2006</th>\n      <td>-2.691027</td>\n    </tr>\n    <tr>\n      <th>海南省</th>\n      <th>2006</th>\n      <td>-2.032787</td>\n    </tr>\n    <tr>\n      <th>甘肃省</th>\n      <th>2006</th>\n      <td>-2.018086</td>\n    </tr>\n    <tr>\n      <th>贵州省</th>\n      <th>2006</th>\n      <td>-1.983439</td>\n    </tr>\n    <tr>\n      <th>新疆维吾尔自治区</th>\n      <th>2006</th>\n      <td>-1.580534</td>\n    </tr>\n    <tr>\n      <th>天津市</th>\n      <th>2006</th>\n      <td>-1.199164</td>\n    </tr>\n    <tr>\n      <th>重庆市</th>\n      <th>2006</th>\n      <td>-1.175635</td>\n    </tr>\n    <tr>\n      <th>云南省</th>\n      <th>2006</th>\n      <td>-1.154074</td>\n    </tr>\n    <tr>\n      <th>吉林省</th>\n      <th>2006</th>\n      <td>-0.958117</td>\n    </tr>\n    <tr>\n      <th>北京市</th>\n      <th>2006</th>\n      <td>-0.860666</td>\n    </tr>\n    <tr>\n      <th>陕西省</th>\n      <th>2006</th>\n      <td>-0.856640</td>\n    </tr>\n    <tr>\n      <th>广西壮族自治区</th>\n      <th>2006</th>\n      <td>-0.784542</td>\n    </tr>\n    <tr>\n      <th>山西省</th>\n      <th>2006</th>\n      <td>-0.649364</td>\n    </tr>\n    <tr>\n      <th>江西省</th>\n      <th>2006</th>\n      <td>-0.553290</td>\n    </tr>\n    <tr>\n      <th>内蒙古自治区</th>\n      <th>2006</th>\n      <td>-0.535727</td>\n    </tr>\n    <tr>\n      <th>上海市</th>\n      <th>2006</th>\n      <td>-0.432001</td>\n    </tr>\n    <tr>\n      <th>福建省</th>\n      <th>2006</th>\n      <td>-0.370248</td>\n    </tr>\n    <tr>\n      <th>安徽省</th>\n      <th>2006</th>\n      <td>-0.231912</td>\n    </tr>\n    <tr>\n      <th>黑龙江省</th>\n      <th>2006</th>\n      <td>-0.117034</td>\n    </tr>\n    <tr>\n      <th>湖北省</th>\n      <th>2006</th>\n      <td>0.246249</td>\n    </tr>\n    <tr>\n      <th>辽宁省</th>\n      <th>2006</th>\n      <td>0.510693</td>\n    </tr>\n    <tr>\n      <th>湖南省</th>\n      <th>2006</th>\n      <td>0.832367</td>\n    </tr>\n    <tr>\n      <th>四川省</th>\n      <th>2006</th>\n      <td>0.930342</td>\n    </tr>\n    <tr>\n      <th>浙江省</th>\n      <th>2006</th>\n      <td>1.158288</td>\n    </tr>\n    <tr>\n      <th>河北省</th>\n      <th>2006</th>\n      <td>2.424997</td>\n    </tr>\n    <tr>\n      <th>河南省</th>\n      <th>2006</th>\n      <td>3.061378</td>\n    </tr>\n    <tr>\n      <th>广东省</th>\n      <th>2006</th>\n      <td>3.356152</td>\n    </tr>\n    <tr>\n      <th>江苏省</th>\n      <th>2006</th>\n      <td>3.691040</td>\n    </tr>\n    <tr>\n      <th>山东省</th>\n      <th>2006</th>\n      <td>5.878337</td>\n    </tr>\n  </tbody>\n</table>'

# %%
with open("table.htm", "w", encoding="utf8") as fp:
    fp.write
